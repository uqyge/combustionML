# %%
from keras.models import load_model
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
model = load_model('FPV_ANN_tabulated_Standard.H5')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 3)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          400         input_1[0][0]
# __________________________________________________________________________________________________
# res1a_branch2a (Dense)          (None, 300)          30300       dense_1[0][0]
# __________________________________________________________________________________________________
# res1a_branch2a_0 (Dense)        (None, 300)          30300       dense_1[0][0]
# __________________________________________________________________________________________________
# res1a_branch2a_1 (Dense)        (None, 300)          30300       dense_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 300)          0           res1a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 300)          0           res1a_branch2a_0[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 300)          0           res1a_branch2a_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 900)          0           activation_1[0][0]
#                                                                  activation_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# res1a_branch2b (Dense)          (None, 100)          90100       concatenate_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 100)          0           res1a_branch2b[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 100)          0           add_1[0][0]
# __________________________________________________________________________________________________
# res1b_branch2a (Dense)          (None, 300)          30300       activation_4[0][0]
# __________________________________________________________________________________________________
# res1b_branch2a_0 (Dense)        (None, 300)          30300       activation_4[0][0]
# __________________________________________________________________________________________________
# res1b_branch2a_1 (Dense)        (None, 300)          30300       activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 300)          0           res1b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 300)          0           res1b_branch2a_0[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 300)          0           res1b_branch2a_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 900)          0           activation_5[0][0]
#                                                                  activation_6[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# res1b_branch2b (Dense)          (None, 100)          90100       concatenate_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 100)          0           res1b_branch2b[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 100)          0           add_2[0][0]
# __________________________________________________________________________________________________
# res1c_branch2a (Dense)          (None, 300)          30300       activation_8[0][0]
# __________________________________________________________________________________________________
# res1c_branch2a_0 (Dense)        (None, 300)          30300       activation_8[0][0]
# __________________________________________________________________________________________________
# res1c_branch2a_1 (Dense)        (None, 300)          30300       activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 300)          0           res1c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 300)          0           res1c_branch2a_0[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 300)          0           res1c_branch2a_1[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 900)          0           activation_9[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# res1c_branch2b (Dense)          (None, 100)          90100       concatenate_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 100)          0           res1c_branch2b[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 100)          0           add_3[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           1010        activation_12[0][0]
# ==================================================================================================
# Total params: 544,410
# Trainable params: 544,410
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /home/eg/anaconda3/envs/my_dev/lib/python3.6/site-packages/keras/engine/saving.py:327: UserWarning: Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
#   warnings.warn('Error in loading the saved optimizer '

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler


class data_scaler(object):
    def __init__(self):
        self.norm = None
        self.norm_1 = None
        self.std = None
        self.case = None
        self.scale = 1
        self.bias = 1e-20
#         self.bias = 1


        self.switcher = {
            'min_std': 'min_std',
            'std2': 'std2',
            'std_min':'std_min',
            'min': 'min',
            'no':'no',
            'log': 'log',
            'log_min':'log_min',
            'log2': 'log2',
            'tan': 'tan'
        }

    def fit_transform(self, input_data, case):
        self.case = case
        if self.switcher.get(self.case) == 'min_std':
            self.norm = MinMaxScaler()
            self.std = StandardScaler()
            out = self.norm.fit_transform(input_data)
            out = self.std.fit_transform(out)

        if self.switcher.get(self.case) == 'std2':
            self.std = StandardScaler()
            out = self.std.fit_transform(input_data)

        if self.switcher.get(self.case) == 'std_min':
            self.norm = MinMaxScaler()
            self.std = StandardScaler()
            out = self.std.fit_transform(input_data)
            out = self.norm.fit_transform(out)

        if self.switcher.get(self.case) == 'min':
            self.norm = MinMaxScaler()
            out = self.norm.fit_transform(input_data)

        if self.switcher.get(self.case) == 'no':
            self.norm = MinMaxScaler()
            self.std = StandardScaler()
            out = input_data

        if self.switcher.get(self.case) == 'log':
            out = - np.log(np.asarray(input_data / self.scale) + self.bias)
            self.std = StandardScaler()
            out = self.std.fit_transform(out)

        if self.switcher.get(self.case) == 'log_min':
            out = - np.log(np.asarray(input_data / self.scale) + self.bias)
            self.norm = MinMaxScaler()
            out = self.norm.fit_transform(out)

        if self.switcher.get(self.case) == 'log2':
            self.norm = MinMaxScaler()
            self.norm_1 = MinMaxScaler()
            out = self.norm.fit_transform(input_data)
            out = np.log(np.asarray(out) + self.bias)
            out = self.norm_1.fit_transform(out)

        if self.switcher.get(self.case) == 'tan':
            self.norm = MaxAbsScaler()
            self.std = StandardScaler()
            out = self.std.fit_transform(input_data)
            out = self.norm.fit_transform(out)
            out = np.tan(out / (2 * np.pi + self.bias))

        return out

    def transform(self, input_data):
        if self.switcher.get(self.case) == 'min_std':
            out = self.norm.transform(input_data)
            out = self.std.transform(out)

        if self.switcher.get(self.case) == 'std2':
            out = self.std.transform(input_data)

        if self.switcher.get(self.case) == 'std_min':
            out = self.std.transform(input_data)
            out = self.norm.transform(out)

        if self.switcher.get(self.case) == 'min':
            out = self.norm.transform(input_data)

        if self.switcher.get(self.case) == 'no':
            out = input_data

        if self.switcher.get(self.case) == 'log':
            out = - np.log(np.asarray(input_data / self.scale) + self.bias)
            out = self.std.transform(out)

        if self.switcher.get(self.case) == 'log_min':
            out = - np.log(np.asarray(input_data / self.scale) + self.bias)
            out = self.norm.transform(out)

        if self.switcher.get(self.case) == 'log2':
            out = self.norm.transform(input_data)
            out = np.log(np.asarray(out) + self.bias)
            out = self.norm_1.transform(out)

        if self.switcher.get(self.case) == 'tan':
            out = self.std.transform(input_data)
            out = self.norm.transform(out)
            out = np.tan(out / (2 * np.pi + self.bias))

        return out

    def inverse_transform(self, input_data):

        if self.switcher.get(self.case) == 'min_std':
            out = self.std.inverse_transform(input_data)
            out = self.norm.inverse_transform(out)

        if self.switcher.get(self.case) == 'std2':
            out = self.std.inverse_transform(input_data)

        if self.switcher.get(self.case) == 'std_min':
            out = self.norm.inverse_transform(input_data)
            out = self.std.inverse_transform(out)

        if self.switcher.get(self.case) == 'min':
            out = self.norm.inverse_transform(input_data)

        if self.switcher.get(self.case) == 'no':
            out = input_data

        if self.switcher.get(self.case) == 'log':
            out = self.std.inverse_transform(input_data)
            out = (np.exp(-out) - self.bias) * self.scale

        if self.switcher.get(self.case) == 'log_min':
            out = self.norm.inverse_transform(input_data)
            out = (np.exp(-out) - self.bias) * self.scale

        if self.switcher.get(self.case) == 'log2':
            out = self.norm_1.inverse_transform(input_data)
            out = np.exp(out) - self.bias
            out = self.norm.inverse_transform(out)

        if self.switcher.get(self.case) == 'tan':
            out = (2 * np.pi + self.bias) * np.arctan(input_data)
            out = self.norm.inverse_transform(out)
            out = self.std.inverse_transform(out)

        return out
      

def read_h5_data(fileName, input_features, labels):
    df = pd.read_hdf(fileName)
#     df = df[df['f']<0.45]
    
    input_df=df[input_features]
    in_scaler = data_scaler()
    input_np = in_scaler.fit_transform(input_df.values,'std2')

    label_df=df[labels].clip(0)
#     if 'PVs' in labels:
#       label_df['PVs']=np.log(label_df['PVs']+1)
    out_scaler = data_scaler()
    label_np = out_scaler.fit_transform(label_df.values,'std2')

    return input_np, label_np, df, in_scaler, out_scaler

# %%
labels = ['CH4','O2','H2O','CO','CO2','T','PVs','psi','mu','alpha']
# labels = ['T','PVs']
# labels = ['T','CH4','O2','CO2','CO','H2O','H2','OH','psi']
# labels = ['CH2OH','HNCO','CH3OH', 'CH2CHO', 'CH2O', 'C3H8', 'HNO', 'NH2', 'HCN']

# labels = np.random.choice(col_labels,20,replace=False).tolist()
# labels.append('PVs')

# labels = col_labels

print(labels)

input_features=['f','zeta','pv']

# read in the data
x_input, y_label, df, in_scaler, out_scaler = read_h5_data('./data/tables_of_fgm.h5',input_features=input_features, labels = labels)
# Out:
# ['CH4', 'O2', 'H2O', 'CO', 'CO2', 'T', 'PVs', 'psi', 'mu', 'alpha']

# %%
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_input,y_label, test_size=0.01)

x_test_df = pd.DataFrame(in_scaler.inverse_transform(x_test),columns=input_features)
y_test_df = pd.DataFrame(out_scaler.inverse_transform(y_test),columns=labels)

predict_val = model.predict(x_test,batch_size=1024*8)
predict_df = pd.DataFrame(out_scaler.inverse_transform(predict_val), columns=labels)

test_data=pd.concat([x_test_df,y_test_df],axis=1)
pred_data=pd.concat([x_test_df,predict_df],axis=1)

# !rm sim_check.h5
test_data.to_hdf('sim_check.h5',key='test')
pred_data.to_hdf('sim_check.h5',key='pred')

df_test=pd.read_hdf('sim_check.h5',key='test')
df_pred=pd.read_hdf('sim_check.h5',key='pred')

zeta_level=list(set(df_test['zeta']))
zeta_level.sort()


res_sum=pd.DataFrame()
r2s=[]
r2s_i=[]

names=[]
maxs_0=[]
maxs_9=[]

for r2,name in zip(r2_score(df_test,df_pred,multioutput='raw_values'),df_test.columns):
  names.append(name)
  r2s.append(r2)
  maxs_0.append(df_test[df_test['zeta']==zeta_level[0]][name].max())
  maxs_9.append(df_test[df_test['zeta']==zeta_level[8]][name].max())
  for i in zeta_level:
    r2s_i.append(r2_score(df_pred[df_pred['zeta']==i][name],
                          df_test[df_test['zeta']==i][name]))

res_sum['name']=names
# res_sum['max_0']=maxs_0
# res_sum['max_9']=maxs_9
res_sum['z_scale']=[m_9/(m_0+1e-20) for m_9,m_0 in zip(maxs_9,maxs_0)]
# res_sum['r2']=r2s


tmp=np.asarray(r2s_i).reshape(-1,10)
for idx,z in enumerate(zeta_level):
  res_sum['r2s_'+str(z)]=tmp[:,idx]

res_sum[3:]
# Out:
#      name   z_scale  r2s_-5.551115123125783e-17  r2s_0.10999999999999999  \
# 3     CH4  1.000000                    0.999991                 0.999993
# 4      O2  1.000000                    0.999979                 0.999984
# 5     H2O  0.223520                    0.999984                 0.999988
# 6      CO  0.182778                    0.999973                 0.999971
# 7     CO2  0.136984                    0.999967                 0.999973
# 8       T  0.309362                    0.999986                 0.999987
# 9     PVs  0.028680                    0.999948                 0.999972
# 10    psi  0.472317                   -5.158790                -4.626245
# 11     mu  0.475050                    0.999986                 0.999990
# 12  alpha  1.000000                    0.999975                 0.999979
#
#     r2s_0.22000000000000003  r2s_0.33  r2s_0.44  r2s_0.55  r2s_0.66  r2s_0.77  \
# 3                  0.999993  0.999992  0.999991  0.999989  0.999986  0.999993
# 4                  0.999985  0.999985  0.999986  0.999986  0.999983  0.999990
# 5                  0.999986  0.999984  0.999983  0.999980  0.999974  0.999956
# 6                  0.999975  0.999967  0.999964  0.999958  0.999936  0.999901
# 7                  0.999973  0.999976  0.999974  0.999966  0.999960  0.999942
# 8                  0.999987  0.999987  0.999985  0.999981  0.999975  0.999969
# 9                  0.999955  0.999936  0.999909  0.999838  0.999807  0.999779
# 10                -4.710263 -3.965601 -3.399584 -2.836254 -2.168430 -1.759963
# 11                 0.999989  0.999988  0.999986  0.999984  0.999983  0.999969
# 12                 0.999980  0.999982  0.999980  0.999980  0.999979  0.999981
#
#     r2s_0.88   r2s_0.99
# 3   0.999991   0.999995
# 4   0.999991   0.999995
# 5   0.999901   0.995556
# 6   0.999725   0.987303
# 7   0.999896   0.997436
# 8   0.999918   0.998187
# 9   0.999550   0.991137
# 10 -2.335879 -11.705524
# 11  0.999944   0.999203
# 12  0.999977   0.999927

# %%
#@title import plotly
import plotly.plotly as py
import numpy as np
from plotly.offline import init_notebook_mode, iplot
# from plotly.graph_objs import Contours, Histogram2dContour, Marker, Scatter
import plotly.graph_objs as go

def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-1.5.1.min.js?noext',
            },
          });
        </script>
        '''))

# %%
#@title Default title text
# species = np.random.choice(labels)
species = 'psi' #@param {type:"string"}
z_level =  0 #@param {type:"integer"}

# configure_plotly_browser_state()
# init_notebook_mode(connected=False)

from sklearn.metrics import r2_score


df_t=df_test[df_test['zeta']==zeta_level[z_level]].sample(frac=1)
# df_p=df_pred.loc[df_pred['zeta']==zeta_level[1]].sample(frac=0.1)
df_p=df_pred.loc[df_t.index]
error=df_p[species]-df_t[species]
r2=round(r2_score(df_p[species],df_t[species]),4)

print(species,'r2:',r2,'max:',df_t[species].max())

fig_db = {
    'data': [       
        {'name':'test data from table',
         'x': df_t['f'],
         'y': df_t['pv'],
         'z': df_t[species],
         'type':'scatter3d', 
        'mode': 'markers',
          'marker':{
              'size':1
          }
        },
        {'name':'prediction from neural networks',
         'x': df_p['f'],
         'y': df_p['pv'],
         'z': df_p[species],
         'type':'scatter3d', 
        'mode': 'markers',
          'marker':{
              'size':1
          },
        },
        {'name':'error in difference',
         'x': df_p['f'],
         'y': df_p['pv'],
         'z': error,
         'type':'scatter3d', 
         'mode': 'markers',
          'marker':{
              'size':1
          },
         }       
    ],
    'layout': {
        'scene':{
            'xaxis': {'title':'mixture fraction'},
            'yaxis': {'title':'progress variable'},
            'zaxis': {'title': species+'_r2:'+str(r2)}
                 }
    }
}
# iplot(fig_db, filename='multiple-scatter')
iplot(fig_db)
# Out:
# psi r2: -5.1588 max: 9.896890000000001e-05

# %%
from keras.models import Model
from keras.layers import Dense, Input, Dropout
from keras.callbacks import ModelCheckpoint


n_neuron = 50
# %%
print('set up student network')
# ANN parameters
dim_input = x_train.shape[1]
dim_label = y_train.shape[1]

batch_norm = False

# This returns a tensor
inputs = Input(shape=(dim_input,),name='input_1')

# a layer instance is callable on a tensor, and returns a tensor
x = Dense(n_neuron, activation='relu')(inputs)
x = Dense(n_neuron, activation='relu')(x)
# x = Dropout(0.1)(x)
predictions = Dense(dim_label, activation='linear', name='output_1')(x)

student_model = Model(inputs=inputs, outputs=predictions)
student_model.summary()
# Out:
# set up student network
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                200
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                2550
# _________________________________________________________________
# output_1 (Dense)             (None, 10)                510
# =================================================================
# Total params: 3,260
# Trainable params: 3,260
# Non-trainable params: 0
# _________________________________________________________________

# %%
student_model.save('student.h5')

# %%
import keras.backend as K
from keras.callbacks import LearningRateScheduler
import math

def cubic_loss(y_true, y_pred):
    return K.mean(K.square(y_true - y_pred)*K.abs(y_true - y_pred), axis=-1)

def coeff_r2(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square( y_true-y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

  
def step_decay(epoch):
   initial_lrate = 0.001
   drop = 0.5
   epochs_drop = 2000.0
   lrate = initial_lrate * math.pow(drop,math.floor((1+epoch)/epochs_drop))
   return lrate
  
lrate = LearningRateScheduler(step_decay)

# %%
from keras import optimizers
batch_size = 1024*32
epochs = 6000
vsplit = 0.1

loss_type='mse'

adam_op = optimizers.Adam(lr=0.00001, beta_1=0.9, beta_2=0.999,epsilon=1e-8, decay=0.0, amsgrad=True)

student_model.compile(loss=loss_type, optimizer=adam_op, metrics=[coeff_r2])
# model.compile(loss=cubic_loss, optimizer=adam_op, metrics=['accuracy'])

# checkpoint (save the best model based validate loss)
# !mkdir ./tmp
filepath = "./tmp/student_weights.best.cntk.hdf5"

checkpoint = ModelCheckpoint(filepath,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True,
                             mode='min',
                             period=20)

# callbacks_list = [checkpoint]
callbacks_list = [lrate]

x_train_teacher = x_train
y_train_teacher = model.predict(x_train, batch_size=1024*8)
# fit the model
history = student_model.fit(
    x_train_teacher, y_train_teacher,
    epochs=epochs,
    batch_size=batch_size,
    validation_split=vsplit,
    verbose=2,
    callbacks=callbacks_list,
    shuffle=True)
# Out:
# mkdir: cannot create directory ‘./tmp’: File exists
# Train on 2236418 samples, validate on 248491 samples
# Epoch 1/6000
#  - 2s - loss: 0.6213 - coeff_r2: 0.3789 - val_loss: 0.2768 - val_coeff_r2: 0.7236
# Epoch 2/6000
#  - 1s - loss: 0.2258 - coeff_r2: 0.7744 - val_loss: 0.1899 - val_coeff_r2: 0.8104
# Epoch 3/6000
#  - 1s - loss: 0.1704 - coeff_r2: 0.8297 - val_loss: 0.1500 - val_coeff_r2: 0.8503
# Epoch 4/6000
#  - 1s - loss: 0.1403 - coeff_r2: 0.8597 - val_loss: 0.1281 - val_coeff_r2: 0.8721
# Epoch 5/6000
#  - 1s - loss: 0.1228 - coeff_r2: 0.8773 - val_loss: 0.1141 - val_coeff_r2: 0.8861
# Epoch 6/6000
#  - 1s - loss: 0.1109 - coeff_r2: 0.8892 - val_loss: 0.1037 - val_coeff_r2: 0.8965
# Epoch 7/6000
#  - 1s - loss: 0.1016 - coeff_r2: 0.8985 - val_loss: 0.0955 - val_coeff_r2: 0.9047
# Epoch 8/6000
#  - 1s - loss: 0.0939 - coeff_r2: 0.9062 - val_loss: 0.0883 - val_coeff_r2: 0.9119
# Epoch 9/6000
#  - 1s - loss: 0.0872 - coeff_r2: 0.9129 - val_loss: 0.0821 - val_coeff_r2: 0.9180
# Epoch 10/6000
#  - 1s - loss: 0.0816 - coeff_r2: 0.9185 - val_loss: 0.0771 - val_coeff_r2: 0.9230
# Epoch 11/6000
#  - 1s - loss: 0.0770 - coeff_r2: 0.9230 - val_loss: 0.0730 - val_coeff_r2: 0.9271
# Epoch 12/6000
#  - 1s - loss: 0.0732 - coeff_r2: 0.9269 - val_loss: 0.0695 - val_coeff_r2: 0.9307
# Epoch 13/6000
#  - 1s - loss: 0.0698 - coeff_r2: 0.9303 - val_loss: 0.0663 - val_coeff_r2: 0.9338
# Epoch 14/6000
#  - 1s - loss: 0.0668 - coeff_r2: 0.9332 - val_loss: 0.0635 - val_coeff_r2: 0.9366
# Epoch 15/6000
#  - 1s - loss: 0.0641 - coeff_r2: 0.9360 - val_loss: 0.0608 - val_coeff_r2: 0.9393
# Epoch 16/6000
#  - 1s - loss: 0.0614 - coeff_r2: 0.9387 - val_loss: 0.0582 - val_coeff_r2: 0.9419
# Epoch 17/6000
#  - 1s - loss: 0.0589 - coeff_r2: 0.9412 - val_loss: 0.0558 - val_coeff_r2: 0.9443
# Epoch 18/6000
#  - 1s - loss: 0.0565 - coeff_r2: 0.9436 - val_loss: 0.0535 - val_coeff_r2: 0.9466
# Epoch 19/6000
#  - 1s - loss: 0.0543 - coeff_r2: 0.9457 - val_loss: 0.0514 - val_coeff_r2: 0.9487
# Epoch 20/6000
#  - 1s - loss: 0.0523 - coeff_r2: 0.9478 - val_loss: 0.0495 - val_coeff_r2: 0.9506
# Epoch 21/6000
#  - 1s - loss: 0.0503 - coeff_r2: 0.9497 - val_loss: 0.0477 - val_coeff_r2: 0.9524
# Epoch 22/6000
#  - 1s - loss: 0.0486 - coeff_r2: 0.9515 - val_loss: 0.0459 - val_coeff_r2: 0.9542
# Epoch 23/6000
#  - 1s - loss: 0.0469 - coeff_r2: 0.9532 - val_loss: 0.0443 - val_coeff_r2: 0.9558
# Epoch 24/6000
#  - 1s - loss: 0.0453 - coeff_r2: 0.9547 - val_loss: 0.0429 - val_coeff_r2: 0.9572
# Epoch 25/6000
#  - 1s - loss: 0.0439 - coeff_r2: 0.9562 - val_loss: 0.0414 - val_coeff_r2: 0.9586
# Epoch 26/6000
#  - 1s - loss: 0.0425 - coeff_r2: 0.9575 - val_loss: 0.0401 - val_coeff_r2: 0.9599
# Epoch 27/6000
#  - 1s - loss: 0.0411 - coeff_r2: 0.9589 - val_loss: 0.0388 - val_coeff_r2: 0.9613
# Epoch 28/6000
#  - 1s - loss: 0.0399 - coeff_r2: 0.9602 - val_loss: 0.0377 - val_coeff_r2: 0.9624
# Epoch 29/6000
#  - 1s - loss: 0.0388 - coeff_r2: 0.9613 - val_loss: 0.0365 - val_coeff_r2: 0.9635
# Epoch 30/6000
#  - 1s - loss: 0.0376 - coeff_r2: 0.9624 - val_loss: 0.0356 - val_coeff_r2: 0.9645
# Epoch 31/6000
#  - 1s - loss: 0.0366 - coeff_r2: 0.9634 - val_loss: 0.0345 - val_coeff_r2: 0.9656
# Epoch 32/6000
#  - 1s - loss: 0.0357 - coeff_r2: 0.9644 - val_loss: 0.0336 - val_coeff_r2: 0.9665
# Epoch 33/6000
#  - 1s - loss: 0.0347 - coeff_r2: 0.9654 - val_loss: 0.0328 - val_coeff_r2: 0.9673
# Epoch 34/6000
#  - 1s - loss: 0.0338 - coeff_r2: 0.9662 - val_loss: 0.0320 - val_coeff_r2: 0.9681
# Epoch 35/6000
#  - 1s - loss: 0.0330 - coeff_r2: 0.9671 - val_loss: 0.0312 - val_coeff_r2: 0.9689
# Epoch 36/6000
#  - 1s - loss: 0.0322 - coeff_r2: 0.9679 - val_loss: 0.0304 - val_coeff_r2: 0.9697
# Epoch 37/6000
#  - 1s - loss: 0.0314 - coeff_r2: 0.9686 - val_loss: 0.0297 - val_coeff_r2: 0.9704
# Epoch 38/6000
#  - 1s - loss: 0.0307 - coeff_r2: 0.9693 - val_loss: 0.0290 - val_coeff_r2: 0.9711
# Epoch 39/6000
#  - 1s - loss: 0.0300 - coeff_r2: 0.9700 - val_loss: 0.0284 - val_coeff_r2: 0.9717
# Epoch 40/6000
#  - 1s - loss: 0.0294 - coeff_r2: 0.9706 - val_loss: 0.0279 - val_coeff_r2: 0.9722
# Epoch 41/6000
#  - 1s - loss: 0.0288 - coeff_r2: 0.9713 - val_loss: 0.0272 - val_coeff_r2: 0.9728
# Epoch 42/6000
#  - 1s - loss: 0.0282 - coeff_r2: 0.9718 - val_loss: 0.0268 - val_coeff_r2: 0.9733
# Epoch 43/6000
#  - 1s - loss: 0.0276 - coeff_r2: 0.9724 - val_loss: 0.0263 - val_coeff_r2: 0.9737
# Epoch 44/6000
#  - 1s - loss: 0.0271 - coeff_r2: 0.9729 - val_loss: 0.0257 - val_coeff_r2: 0.9743
# Epoch 45/6000
#  - 1s - loss: 0.0266 - coeff_r2: 0.9734 - val_loss: 0.0252 - val_coeff_r2: 0.9748
# Epoch 46/6000
#  - 1s - loss: 0.0261 - coeff_r2: 0.9739 - val_loss: 0.0247 - val_coeff_r2: 0.9753
# Epoch 47/6000
#  - 1s - loss: 0.0256 - coeff_r2: 0.9744 - val_loss: 0.0244 - val_coeff_r2: 0.9756
# Epoch 48/6000
#  - 1s - loss: 0.0252 - coeff_r2: 0.9748 - val_loss: 0.0238 - val_coeff_r2: 0.9763
# Epoch 49/6000
#  - 1s - loss: 0.0248 - coeff_r2: 0.9753 - val_loss: 0.0235 - val_coeff_r2: 0.9766
# Epoch 50/6000
#  - 1s - loss: 0.0243 - coeff_r2: 0.9757 - val_loss: 0.0231 - val_coeff_r2: 0.9770
# Epoch 51/6000
#  - 1s - loss: 0.0240 - coeff_r2: 0.9761 - val_loss: 0.0227 - val_coeff_r2: 0.9774
# Epoch 52/6000
#  - 1s - loss: 0.0236 - coeff_r2: 0.9765 - val_loss: 0.0226 - val_coeff_r2: 0.9774
# Epoch 53/6000
#  - 1s - loss: 0.0232 - coeff_r2: 0.9768 - val_loss: 0.0220 - val_coeff_r2: 0.9781
# Epoch 54/6000
#  - 1s - loss: 0.0228 - coeff_r2: 0.9772 - val_loss: 0.0218 - val_coeff_r2: 0.9782
# Epoch 55/6000
#  - 1s - loss: 0.0225 - coeff_r2: 0.9775 - val_loss: 0.0214 - val_coeff_r2: 0.9786
# Epoch 56/6000
#  - 1s - loss: 0.0222 - coeff_r2: 0.9778 - val_loss: 0.0212 - val_coeff_r2: 0.9788
# Epoch 57/6000
#  - 1s - loss: 0.0219 - coeff_r2: 0.9781 - val_loss: 0.0208 - val_coeff_r2: 0.9792
# Epoch 58/6000
#  - 1s - loss: 0.0216 - coeff_r2: 0.9785 - val_loss: 0.0205 - val_coeff_r2: 0.9795
# Epoch 59/6000
#  - 1s - loss: 0.0213 - coeff_r2: 0.9788 - val_loss: 0.0202 - val_coeff_r2: 0.9798
# Epoch 60/6000
#  - 1s - loss: 0.0210 - coeff_r2: 0.9791 - val_loss: 0.0199 - val_coeff_r2: 0.9801
# Epoch 61/6000
#  - 1s - loss: 0.0207 - coeff_r2: 0.9794 - val_loss: 0.0199 - val_coeff_r2: 0.9802
# Epoch 62/6000
#  - 1s - loss: 0.0204 - coeff_r2: 0.9796 - val_loss: 0.0194 - val_coeff_r2: 0.9806
# Epoch 63/6000
#  - 1s - loss: 0.0201 - coeff_r2: 0.9799 - val_loss: 0.0192 - val_coeff_r2: 0.9808
# Epoch 64/6000
#  - 1s - loss: 0.0199 - coeff_r2: 0.9801 - val_loss: 0.0191 - val_coeff_r2: 0.9809
# Epoch 65/6000
#  - 1s - loss: 0.0197 - coeff_r2: 0.9803 - val_loss: 0.0188 - val_coeff_r2: 0.9812
# Epoch 66/6000
#  - 1s - loss: 0.0194 - coeff_r2: 0.9806 - val_loss: 0.0186 - val_coeff_r2: 0.9814
# Epoch 67/6000
#  - 1s - loss: 0.0192 - coeff_r2: 0.9808 - val_loss: 0.0183 - val_coeff_r2: 0.9817
# Epoch 68/6000
#  - 1s - loss: 0.0190 - coeff_r2: 0.9810 - val_loss: 0.0182 - val_coeff_r2: 0.9818
# Epoch 69/6000
#  - 1s - loss: 0.0187 - coeff_r2: 0.9813 - val_loss: 0.0180 - val_coeff_r2: 0.9820
# Epoch 70/6000
#  - 1s - loss: 0.0185 - coeff_r2: 0.9815 - val_loss: 0.0178 - val_coeff_r2: 0.9823
# Epoch 71/6000
#  - 1s - loss: 0.0183 - coeff_r2: 0.9817 - val_loss: 0.0175 - val_coeff_r2: 0.9825
# Epoch 72/6000
#  - 1s - loss: 0.0182 - coeff_r2: 0.9819 - val_loss: 0.0174 - val_coeff_r2: 0.9826
# Epoch 73/6000
#  - 1s - loss: 0.0179 - coeff_r2: 0.9821 - val_loss: 0.0172 - val_coeff_r2: 0.9828
# Epoch 74/6000
#  - 1s - loss: 0.0178 - coeff_r2: 0.9823 - val_loss: 0.0170 - val_coeff_r2: 0.9830
# Epoch 75/6000
#  - 1s - loss: 0.0175 - coeff_r2: 0.9825 - val_loss: 0.0170 - val_coeff_r2: 0.9830
# Epoch 76/6000
#  - 1s - loss: 0.0174 - coeff_r2: 0.9826 - val_loss: 0.0168 - val_coeff_r2: 0.9832
# Epoch 77/6000
#  - 1s - loss: 0.0173 - coeff_r2: 0.9828 - val_loss: 0.0166 - val_coeff_r2: 0.9834
# Epoch 78/6000
#  - 1s - loss: 0.0171 - coeff_r2: 0.9830 - val_loss: 0.0165 - val_coeff_r2: 0.9836
# Epoch 79/6000
#  - 1s - loss: 0.0169 - coeff_r2: 0.9832 - val_loss: 0.0162 - val_coeff_r2: 0.9838
# Epoch 80/6000
#  - 1s - loss: 0.0167 - coeff_r2: 0.9833 - val_loss: 0.0160 - val_coeff_r2: 0.9840
# Epoch 81/6000
#  - 1s - loss: 0.0165 - coeff_r2: 0.9835 - val_loss: 0.0159 - val_coeff_r2: 0.9841
# Epoch 82/6000
#  - 1s - loss: 0.0164 - coeff_r2: 0.9836 - val_loss: 0.0159 - val_coeff_r2: 0.9841
# Epoch 83/6000
#  - 1s - loss: 0.0162 - coeff_r2: 0.9838 - val_loss: 0.0157 - val_coeff_r2: 0.9843
# Epoch 84/6000
#  - 1s - loss: 0.0161 - coeff_r2: 0.9840 - val_loss: 0.0155 - val_coeff_r2: 0.9845
# Epoch 85/6000
#  - 1s - loss: 0.0159 - coeff_r2: 0.9841 - val_loss: 0.0154 - val_coeff_r2: 0.9846
# Epoch 86/6000
#  - 1s - loss: 0.0158 - coeff_r2: 0.9842 - val_loss: 0.0153 - val_coeff_r2: 0.9847
# Epoch 87/6000
#  - 1s - loss: 0.0157 - coeff_r2: 0.9843 - val_loss: 0.0151 - val_coeff_r2: 0.9849
# Epoch 88/6000
#  - 1s - loss: 0.0155 - coeff_r2: 0.9845 - val_loss: 0.0150 - val_coeff_r2: 0.9850
# Epoch 89/6000
#  - 1s - loss: 0.0154 - coeff_r2: 0.9846 - val_loss: 0.0149 - val_coeff_r2: 0.9851
# Epoch 90/6000
#  - 1s - loss: 0.0153 - coeff_r2: 0.9847 - val_loss: 0.0148 - val_coeff_r2: 0.9852
# Epoch 91/6000
#  - 1s - loss: 0.0151 - coeff_r2: 0.9849 - val_loss: 0.0147 - val_coeff_r2: 0.9854
# Epoch 92/6000
#  - 1s - loss: 0.0150 - coeff_r2: 0.9850 - val_loss: 0.0145 - val_coeff_r2: 0.9855
# Epoch 93/6000
#  - 1s - loss: 0.0148 - coeff_r2: 0.9852 - val_loss: 0.0145 - val_coeff_r2: 0.9855
# Epoch 94/6000
#  - 1s - loss: 0.0148 - coeff_r2: 0.9853 - val_loss: 0.0143 - val_coeff_r2: 0.9858
# Epoch 95/6000
#  - 1s - loss: 0.0146 - coeff_r2: 0.9854 - val_loss: 0.0143 - val_coeff_r2: 0.9857
# Epoch 96/6000
#  - 1s - loss: 0.0145 - coeff_r2: 0.9855 - val_loss: 0.0141 - val_coeff_r2: 0.9860
# Epoch 97/6000
#  - 1s - loss: 0.0144 - coeff_r2: 0.9856 - val_loss: 0.0139 - val_coeff_r2: 0.9861
# Epoch 98/6000
#  - 1s - loss: 0.0142 - coeff_r2: 0.9858 - val_loss: 0.0139 - val_coeff_r2: 0.9861
# Epoch 99/6000
#  - 1s - loss: 0.0141 - coeff_r2: 0.9859 - val_loss: 0.0137 - val_coeff_r2: 0.9863
# Epoch 100/6000
#  - 1s - loss: 0.0140 - coeff_r2: 0.9860 - val_loss: 0.0137 - val_coeff_r2: 0.9863
# Epoch 101/6000
#  - 1s - loss: 0.0139 - coeff_r2: 0.9861 - val_loss: 0.0135 - val_coeff_r2: 0.9865
# Epoch 102/6000
#  - 1s - loss: 0.0138 - coeff_r2: 0.9862 - val_loss: 0.0133 - val_coeff_r2: 0.9867
# Epoch 103/6000
#  - 1s - loss: 0.0137 - coeff_r2: 0.9864 - val_loss: 0.0134 - val_coeff_r2: 0.9867
# Epoch 104/6000
#  - 1s - loss: 0.0136 - coeff_r2: 0.9865 - val_loss: 0.0134 - val_coeff_r2: 0.9866
# Epoch 105/6000
#  - 1s - loss: 0.0134 - coeff_r2: 0.9866 - val_loss: 0.0131 - val_coeff_r2: 0.9869
# Epoch 106/6000
#  - 1s - loss: 0.0134 - coeff_r2: 0.9867 - val_loss: 0.0131 - val_coeff_r2: 0.9869
# Epoch 107/6000
#  - 1s - loss: 0.0133 - coeff_r2: 0.9867 - val_loss: 0.0131 - val_coeff_r2: 0.9870
# Epoch 108/6000
#  - 1s - loss: 0.0132 - coeff_r2: 0.9868 - val_loss: 0.0128 - val_coeff_r2: 0.9873
# Epoch 109/6000
#  - 1s - loss: 0.0130 - coeff_r2: 0.9870 - val_loss: 0.0127 - val_coeff_r2: 0.9873
# Epoch 110/6000
#  - 1s - loss: 0.0129 - coeff_r2: 0.9871 - val_loss: 0.0126 - val_coeff_r2: 0.9874
# Epoch 111/6000
#  - 1s - loss: 0.0128 - coeff_r2: 0.9872 - val_loss: 0.0125 - val_coeff_r2: 0.9875
# Epoch 112/6000
#  - 1s - loss: 0.0127 - coeff_r2: 0.9873 - val_loss: 0.0127 - val_coeff_r2: 0.9873
# Epoch 113/6000
#  - 1s - loss: 0.0127 - coeff_r2: 0.9873 - val_loss: 0.0125 - val_coeff_r2: 0.9875
# Epoch 114/6000
#  - 1s - loss: 0.0126 - coeff_r2: 0.9874 - val_loss: 0.0122 - val_coeff_r2: 0.9879
# Epoch 115/6000
#  - 1s - loss: 0.0124 - coeff_r2: 0.9876 - val_loss: 0.0122 - val_coeff_r2: 0.9878
# Epoch 116/6000
#  - 1s - loss: 0.0123 - coeff_r2: 0.9877 - val_loss: 0.0121 - val_coeff_r2: 0.9879
# Epoch 117/6000
#  - 1s - loss: 0.0123 - coeff_r2: 0.9878 - val_loss: 0.0120 - val_coeff_r2: 0.9880
# Epoch 118/6000
#  - 1s - loss: 0.0122 - coeff_r2: 0.9878 - val_loss: 0.0119 - val_coeff_r2: 0.9881
# Epoch 119/6000
#  - 1s - loss: 0.0120 - coeff_r2: 0.9880 - val_loss: 0.0118 - val_coeff_r2: 0.9882
# Epoch 120/6000
#  - 1s - loss: 0.0120 - coeff_r2: 0.9881 - val_loss: 0.0118 - val_coeff_r2: 0.9883
# Epoch 121/6000
#  - 1s - loss: 0.0119 - coeff_r2: 0.9881 - val_loss: 0.0117 - val_coeff_r2: 0.9884
# Epoch 122/6000
#  - 1s - loss: 0.0118 - coeff_r2: 0.9882 - val_loss: 0.0115 - val_coeff_r2: 0.9885
# Epoch 123/6000
#  - 1s - loss: 0.0118 - coeff_r2: 0.9882 - val_loss: 0.0116 - val_coeff_r2: 0.9884
# Epoch 124/6000
#  - 1s - loss: 0.0117 - coeff_r2: 0.9884 - val_loss: 0.0114 - val_coeff_r2: 0.9887
# Epoch 125/6000
#  - 1s - loss: 0.0115 - coeff_r2: 0.9885 - val_loss: 0.0116 - val_coeff_r2: 0.9885
# Epoch 126/6000
#  - 1s - loss: 0.0115 - coeff_r2: 0.9885 - val_loss: 0.0112 - val_coeff_r2: 0.9888
# Epoch 127/6000
#  - 1s - loss: 0.0114 - coeff_r2: 0.9886 - val_loss: 0.0112 - val_coeff_r2: 0.9888
# Epoch 128/6000
#  - 1s - loss: 0.0113 - coeff_r2: 0.9887 - val_loss: 0.0110 - val_coeff_r2: 0.9890
# Epoch 129/6000
#  - 1s - loss: 0.0112 - coeff_r2: 0.9888 - val_loss: 0.0111 - val_coeff_r2: 0.9889
# Epoch 130/6000
#  - 1s - loss: 0.0111 - coeff_r2: 0.9889 - val_loss: 0.0109 - val_coeff_r2: 0.9891
# Epoch 131/6000
#  - 1s - loss: 0.0111 - coeff_r2: 0.9889 - val_loss: 0.0109 - val_coeff_r2: 0.9891
# Epoch 132/6000
#  - 1s - loss: 0.0110 - coeff_r2: 0.9891 - val_loss: 0.0108 - val_coeff_r2: 0.9893
# Epoch 133/6000
#  - 1s - loss: 0.0109 - coeff_r2: 0.9891 - val_loss: 0.0107 - val_coeff_r2: 0.9893
# Epoch 134/6000
#  - 1s - loss: 0.0108 - coeff_r2: 0.9892 - val_loss: 0.0107 - val_coeff_r2: 0.9893
# Epoch 135/6000
#  - 1s - loss: 0.0107 - coeff_r2: 0.9893 - val_loss: 0.0106 - val_coeff_r2: 0.9894
# Epoch 136/6000
#  - 1s - loss: 0.0107 - coeff_r2: 0.9894 - val_loss: 0.0105 - val_coeff_r2: 0.9895
# Epoch 137/6000
#  - 1s - loss: 0.0106 - coeff_r2: 0.9894 - val_loss: 0.0105 - val_coeff_r2: 0.9895
# Epoch 138/6000
#  - 1s - loss: 0.0105 - coeff_r2: 0.9895 - val_loss: 0.0104 - val_coeff_r2: 0.9896
# Epoch 139/6000
#  - 1s - loss: 0.0105 - coeff_r2: 0.9895 - val_loss: 0.0103 - val_coeff_r2: 0.9897
# Epoch 140/6000
#  - 1s - loss: 0.0104 - coeff_r2: 0.9896 - val_loss: 0.0102 - val_coeff_r2: 0.9898
# Epoch 141/6000
#  - 1s - loss: 0.0103 - coeff_r2: 0.9897 - val_loss: 0.0101 - val_coeff_r2: 0.9899
# Epoch 142/6000
#  - 1s - loss: 0.0102 - coeff_r2: 0.9898 - val_loss: 0.0100 - val_coeff_r2: 0.9900
# Epoch 143/6000
#  - 1s - loss: 0.0102 - coeff_r2: 0.9898 - val_loss: 0.0101 - val_coeff_r2: 0.9899
# Epoch 144/6000
#  - 1s - loss: 0.0101 - coeff_r2: 0.9899 - val_loss: 0.0103 - val_coeff_r2: 0.9897
# Epoch 145/6000
#  - 1s - loss: 0.0101 - coeff_r2: 0.9899 - val_loss: 0.0099 - val_coeff_r2: 0.9902
# Epoch 146/6000
#  - 1s - loss: 0.0099 - coeff_r2: 0.9901 - val_loss: 0.0099 - val_coeff_r2: 0.9901
# Epoch 147/6000
#  - 1s - loss: 0.0099 - coeff_r2: 0.9901 - val_loss: 0.0097 - val_coeff_r2: 0.9903
# Epoch 148/6000
#  - 1s - loss: 0.0098 - coeff_r2: 0.9902 - val_loss: 0.0097 - val_coeff_r2: 0.9903
# Epoch 149/6000
#  - 1s - loss: 0.0098 - coeff_r2: 0.9903 - val_loss: 0.0096 - val_coeff_r2: 0.9904
# Epoch 150/6000
#  - 1s - loss: 0.0097 - coeff_r2: 0.9903 - val_loss: 0.0097 - val_coeff_r2: 0.9903
# Epoch 151/6000
#  - 1s - loss: 0.0096 - coeff_r2: 0.9904 - val_loss: 0.0095 - val_coeff_r2: 0.9905
# Epoch 152/6000
#  - 1s - loss: 0.0096 - coeff_r2: 0.9904 - val_loss: 0.0095 - val_coeff_r2: 0.9905
# Epoch 153/6000
#  - 1s - loss: 0.0095 - coeff_r2: 0.9905 - val_loss: 0.0094 - val_coeff_r2: 0.9906
# Epoch 154/6000
#  - 1s - loss: 0.0094 - coeff_r2: 0.9906 - val_loss: 0.0093 - val_coeff_r2: 0.9907
# Epoch 155/6000
#  - 1s - loss: 0.0094 - coeff_r2: 0.9906 - val_loss: 0.0092 - val_coeff_r2: 0.9908
# Epoch 156/6000
#  - 1s - loss: 0.0093 - coeff_r2: 0.9907 - val_loss: 0.0092 - val_coeff_r2: 0.9908
# Epoch 157/6000
#  - 1s - loss: 0.0092 - coeff_r2: 0.9908 - val_loss: 0.0093 - val_coeff_r2: 0.9907
# Epoch 158/6000
#  - 1s - loss: 0.0092 - coeff_r2: 0.9908 - val_loss: 0.0092 - val_coeff_r2: 0.9908
# Epoch 159/6000
#  - 1s - loss: 0.0092 - coeff_r2: 0.9908 - val_loss: 0.0090 - val_coeff_r2: 0.9910
# Epoch 160/6000
#  - 1s - loss: 0.0090 - coeff_r2: 0.9910 - val_loss: 0.0090 - val_coeff_r2: 0.9911
# Epoch 161/6000
#  - 1s - loss: 0.0090 - coeff_r2: 0.9910 - val_loss: 0.0089 - val_coeff_r2: 0.9911
# Epoch 162/6000
#  - 1s - loss: 0.0090 - coeff_r2: 0.9910 - val_loss: 0.0089 - val_coeff_r2: 0.9911
# Epoch 163/6000
#  - 1s - loss: 0.0089 - coeff_r2: 0.9911 - val_loss: 0.0088 - val_coeff_r2: 0.9912
# Epoch 164/6000
#  - 1s - loss: 0.0088 - coeff_r2: 0.9912 - val_loss: 0.0088 - val_coeff_r2: 0.9912
# Epoch 165/6000
#  - 1s - loss: 0.0088 - coeff_r2: 0.9912 - val_loss: 0.0087 - val_coeff_r2: 0.9913
# Epoch 166/6000
#  - 1s - loss: 0.0087 - coeff_r2: 0.9913 - val_loss: 0.0086 - val_coeff_r2: 0.9914
# Epoch 167/6000
#  - 1s - loss: 0.0087 - coeff_r2: 0.9913 - val_loss: 0.0086 - val_coeff_r2: 0.9914
# Epoch 168/6000
#  - 1s - loss: 0.0086 - coeff_r2: 0.9914 - val_loss: 0.0086 - val_coeff_r2: 0.9914
# Epoch 169/6000
#  - 1s - loss: 0.0085 - coeff_r2: 0.9915 - val_loss: 0.0084 - val_coeff_r2: 0.9916
# Epoch 170/6000
#  - 1s - loss: 0.0085 - coeff_r2: 0.9915 - val_loss: 0.0083 - val_coeff_r2: 0.9917
# Epoch 171/6000
#  - 1s - loss: 0.0084 - coeff_r2: 0.9916 - val_loss: 0.0084 - val_coeff_r2: 0.9916
# Epoch 172/6000
#  - 1s - loss: 0.0084 - coeff_r2: 0.9916 - val_loss: 0.0083 - val_coeff_r2: 0.9917
# Epoch 173/6000
#  - 1s - loss: 0.0083 - coeff_r2: 0.9917 - val_loss: 0.0083 - val_coeff_r2: 0.9918
# Epoch 174/6000
#  - 1s - loss: 0.0083 - coeff_r2: 0.9917 - val_loss: 0.0082 - val_coeff_r2: 0.9918
# Epoch 175/6000
#  - 1s - loss: 0.0082 - coeff_r2: 0.9918 - val_loss: 0.0083 - val_coeff_r2: 0.9917
# Epoch 176/6000
#  - 1s - loss: 0.0082 - coeff_r2: 0.9918 - val_loss: 0.0082 - val_coeff_r2: 0.9919
# Epoch 177/6000
#  - 1s - loss: 0.0081 - coeff_r2: 0.9919 - val_loss: 0.0080 - val_coeff_r2: 0.9920
# Epoch 178/6000
#  - 1s - loss: 0.0081 - coeff_r2: 0.9919 - val_loss: 0.0081 - val_coeff_r2: 0.9919
# Epoch 179/6000
#  - 1s - loss: 0.0080 - coeff_r2: 0.9920 - val_loss: 0.0080 - val_coeff_r2: 0.9920
# Epoch 180/6000
#  - 1s - loss: 0.0079 - coeff_r2: 0.9921 - val_loss: 0.0079 - val_coeff_r2: 0.9921
# Epoch 181/6000
#  - 1s - loss: 0.0079 - coeff_r2: 0.9921 - val_loss: 0.0078 - val_coeff_r2: 0.9922
# Epoch 182/6000
#  - 1s - loss: 0.0078 - coeff_r2: 0.9922 - val_loss: 0.0079 - val_coeff_r2: 0.9921
# Epoch 183/6000
#  - 1s - loss: 0.0078 - coeff_r2: 0.9922 - val_loss: 0.0077 - val_coeff_r2: 0.9923
# Epoch 184/6000
#  - 1s - loss: 0.0078 - coeff_r2: 0.9922 - val_loss: 0.0077 - val_coeff_r2: 0.9923
# Epoch 185/6000
#  - 1s - loss: 0.0077 - coeff_r2: 0.9923 - val_loss: 0.0077 - val_coeff_r2: 0.9923
# Epoch 186/6000
#  - 1s - loss: 0.0076 - coeff_r2: 0.9924 - val_loss: 0.0076 - val_coeff_r2: 0.9924
# Epoch 187/6000
#  - 1s - loss: 0.0076 - coeff_r2: 0.9924 - val_loss: 0.0075 - val_coeff_r2: 0.9925
# Epoch 188/6000
#  - 1s - loss: 0.0076 - coeff_r2: 0.9924 - val_loss: 0.0075 - val_coeff_r2: 0.9925
# Epoch 189/6000
#  - 1s - loss: 0.0075 - coeff_r2: 0.9925 - val_loss: 0.0075 - val_coeff_r2: 0.9925
# Epoch 190/6000
#  - 1s - loss: 0.0074 - coeff_r2: 0.9926 - val_loss: 0.0074 - val_coeff_r2: 0.9926
# Epoch 191/6000
#  - 1s - loss: 0.0074 - coeff_r2: 0.9926 - val_loss: 0.0073 - val_coeff_r2: 0.9927
# Epoch 192/6000
#  - 1s - loss: 0.0074 - coeff_r2: 0.9926 - val_loss: 0.0073 - val_coeff_r2: 0.9927
# Epoch 193/6000
#  - 1s - loss: 0.0073 - coeff_r2: 0.9927 - val_loss: 0.0072 - val_coeff_r2: 0.9928
# Epoch 194/6000
#  - 1s - loss: 0.0073 - coeff_r2: 0.9927 - val_loss: 0.0072 - val_coeff_r2: 0.9928
# Epoch 195/6000
#  - 1s - loss: 0.0073 - coeff_r2: 0.9927 - val_loss: 0.0073 - val_coeff_r2: 0.9928
# Epoch 196/6000
#  - 1s - loss: 0.0072 - coeff_r2: 0.9928 - val_loss: 0.0071 - val_coeff_r2: 0.9929
# Epoch 197/6000
#  - 1s - loss: 0.0071 - coeff_r2: 0.9929 - val_loss: 0.0070 - val_coeff_r2: 0.9930
# Epoch 198/6000
#  - 1s - loss: 0.0071 - coeff_r2: 0.9929 - val_loss: 0.0073 - val_coeff_r2: 0.9927
# Epoch 199/6000
#  - 1s - loss: 0.0071 - coeff_r2: 0.9929 - val_loss: 0.0071 - val_coeff_r2: 0.9929
# Epoch 200/6000
#  - 1s - loss: 0.0070 - coeff_r2: 0.9930 - val_loss: 0.0072 - val_coeff_r2: 0.9928
# Epoch 201/6000
#  - 1s - loss: 0.0070 - coeff_r2: 0.9930 - val_loss: 0.0069 - val_coeff_r2: 0.9931
# Epoch 202/6000
#  - 1s - loss: 0.0070 - coeff_r2: 0.9930 - val_loss: 0.0069 - val_coeff_r2: 0.9931
# Epoch 203/6000
#  - 1s - loss: 0.0069 - coeff_r2: 0.9931 - val_loss: 0.0069 - val_coeff_r2: 0.9931
# Epoch 204/6000
#  - 1s - loss: 0.0069 - coeff_r2: 0.9931 - val_loss: 0.0070 - val_coeff_r2: 0.9931
# Epoch 205/6000
#  - 1s - loss: 0.0069 - coeff_r2: 0.9931 - val_loss: 0.0069 - val_coeff_r2: 0.9931
# Epoch 206/6000
#  - 1s - loss: 0.0068 - coeff_r2: 0.9932 - val_loss: 0.0068 - val_coeff_r2: 0.9932
# Epoch 207/6000
#  - 1s - loss: 0.0068 - coeff_r2: 0.9932 - val_loss: 0.0067 - val_coeff_r2: 0.9933
# Epoch 208/6000
#  - 1s - loss: 0.0068 - coeff_r2: 0.9932 - val_loss: 0.0066 - val_coeff_r2: 0.9934
# Epoch 209/6000
#  - 1s - loss: 0.0066 - coeff_r2: 0.9934 - val_loss: 0.0066 - val_coeff_r2: 0.9934
# Epoch 210/6000
#  - 1s - loss: 0.0066 - coeff_r2: 0.9934 - val_loss: 0.0066 - val_coeff_r2: 0.9934
# Epoch 211/6000
#  - 1s - loss: 0.0066 - coeff_r2: 0.9934 - val_loss: 0.0065 - val_coeff_r2: 0.9935
# Epoch 212/6000
#  - 1s - loss: 0.0065 - coeff_r2: 0.9935 - val_loss: 0.0066 - val_coeff_r2: 0.9934
# Epoch 213/6000
#  - 1s - loss: 0.0065 - coeff_r2: 0.9935 - val_loss: 0.0065 - val_coeff_r2: 0.9936
# Epoch 214/6000
#  - 1s - loss: 0.0065 - coeff_r2: 0.9935 - val_loss: 0.0065 - val_coeff_r2: 0.9935
# Epoch 215/6000
#  - 1s - loss: 0.0065 - coeff_r2: 0.9936 - val_loss: 0.0065 - val_coeff_r2: 0.9935
# Epoch 216/6000
#  - 1s - loss: 0.0064 - coeff_r2: 0.9936 - val_loss: 0.0064 - val_coeff_r2: 0.9936
# Epoch 217/6000
#  - 1s - loss: 0.0064 - coeff_r2: 0.9936 - val_loss: 0.0063 - val_coeff_r2: 0.9937
# Epoch 218/6000
#  - 1s - loss: 0.0063 - coeff_r2: 0.9937 - val_loss: 0.0064 - val_coeff_r2: 0.9936
# Epoch 219/6000
#  - 1s - loss: 0.0063 - coeff_r2: 0.9937 - val_loss: 0.0063 - val_coeff_r2: 0.9937
# Epoch 220/6000
#  - 1s - loss: 0.0063 - coeff_r2: 0.9937 - val_loss: 0.0062 - val_coeff_r2: 0.9938
# Epoch 221/6000
#  - 1s - loss: 0.0063 - coeff_r2: 0.9937 - val_loss: 0.0063 - val_coeff_r2: 0.9937
# Epoch 222/6000
#  - 1s - loss: 0.0062 - coeff_r2: 0.9938 - val_loss: 0.0062 - val_coeff_r2: 0.9938
# Epoch 223/6000
#  - 1s - loss: 0.0061 - coeff_r2: 0.9939 - val_loss: 0.0062 - val_coeff_r2: 0.9939
# Epoch 224/6000
#  - 1s - loss: 0.0062 - coeff_r2: 0.9938 - val_loss: 0.0065 - val_coeff_r2: 0.9935
# Epoch 225/6000
#  - 1s - loss: 0.0062 - coeff_r2: 0.9938 - val_loss: 0.0061 - val_coeff_r2: 0.9939
# Epoch 226/6000
#  - 1s - loss: 0.0061 - coeff_r2: 0.9939 - val_loss: 0.0061 - val_coeff_r2: 0.9939
# Epoch 227/6000
#  - 1s - loss: 0.0061 - coeff_r2: 0.9939 - val_loss: 0.0060 - val_coeff_r2: 0.9940
# Epoch 228/6000
#  - 1s - loss: 0.0060 - coeff_r2: 0.9940 - val_loss: 0.0061 - val_coeff_r2: 0.9939
# Epoch 229/6000
#  - 1s - loss: 0.0060 - coeff_r2: 0.9940 - val_loss: 0.0060 - val_coeff_r2: 0.9940
# Epoch 230/6000
#  - 1s - loss: 0.0059 - coeff_r2: 0.9941 - val_loss: 0.0059 - val_coeff_r2: 0.9941
# Epoch 231/6000
#  - 1s - loss: 0.0059 - coeff_r2: 0.9941 - val_loss: 0.0059 - val_coeff_r2: 0.9941
# Epoch 232/6000
#  - 1s - loss: 0.0059 - coeff_r2: 0.9941 - val_loss: 0.0059 - val_coeff_r2: 0.9941
# Epoch 233/6000
#  - 1s - loss: 0.0059 - coeff_r2: 0.9941 - val_loss: 0.0060 - val_coeff_r2: 0.9940
# Epoch 234/6000
#  - 1s - loss: 0.0059 - coeff_r2: 0.9941 - val_loss: 0.0059 - val_coeff_r2: 0.9941
# Epoch 235/6000
#  - 1s - loss: 0.0058 - coeff_r2: 0.9942 - val_loss: 0.0058 - val_coeff_r2: 0.9942
# Epoch 236/6000
#  - 1s - loss: 0.0058 - coeff_r2: 0.9942 - val_loss: 0.0057 - val_coeff_r2: 0.9943
# Epoch 237/6000
#  - 1s - loss: 0.0058 - coeff_r2: 0.9942 - val_loss: 0.0057 - val_coeff_r2: 0.9943
# Epoch 238/6000
#  - 1s - loss: 0.0057 - coeff_r2: 0.9943 - val_loss: 0.0058 - val_coeff_r2: 0.9942
# Epoch 239/6000
#  - 1s - loss: 0.0057 - coeff_r2: 0.9943 - val_loss: 0.0056 - val_coeff_r2: 0.9944
# Epoch 240/6000
#  - 1s - loss: 0.0056 - coeff_r2: 0.9944 - val_loss: 0.0057 - val_coeff_r2: 0.9943
# Epoch 241/6000
#  - 1s - loss: 0.0056 - coeff_r2: 0.9944 - val_loss: 0.0057 - val_coeff_r2: 0.9943
# Epoch 242/6000
#  - 1s - loss: 0.0056 - coeff_r2: 0.9944 - val_loss: 0.0055 - val_coeff_r2: 0.9945
# Epoch 243/6000
#  - 1s - loss: 0.0055 - coeff_r2: 0.9945 - val_loss: 0.0056 - val_coeff_r2: 0.9944
# Epoch 244/6000
#  - 1s - loss: 0.0055 - coeff_r2: 0.9945 - val_loss: 0.0055 - val_coeff_r2: 0.9945
# Epoch 245/6000
#  - 1s - loss: 0.0055 - coeff_r2: 0.9945 - val_loss: 0.0055 - val_coeff_r2: 0.9945
# Epoch 246/6000
#  - 1s - loss: 0.0055 - coeff_r2: 0.9945 - val_loss: 0.0055 - val_coeff_r2: 0.9945
# Epoch 247/6000
#  - 1s - loss: 0.0054 - coeff_r2: 0.9946 - val_loss: 0.0054 - val_coeff_r2: 0.9946
# Epoch 248/6000
#  - 1s - loss: 0.0054 - coeff_r2: 0.9946 - val_loss: 0.0054 - val_coeff_r2: 0.9946
# Epoch 249/6000
#  - 1s - loss: 0.0054 - coeff_r2: 0.9946 - val_loss: 0.0054 - val_coeff_r2: 0.9946
# Epoch 250/6000
#  - 1s - loss: 0.0053 - coeff_r2: 0.9947 - val_loss: 0.0054 - val_coeff_r2: 0.9946
# Epoch 251/6000
#  - 1s - loss: 0.0053 - coeff_r2: 0.9947 - val_loss: 0.0053 - val_coeff_r2: 0.9947
# Epoch 252/6000
#  - 1s - loss: 0.0053 - coeff_r2: 0.9947 - val_loss: 0.0052 - val_coeff_r2: 0.9948
# Epoch 253/6000
#  - 1s - loss: 0.0053 - coeff_r2: 0.9947 - val_loss: 0.0052 - val_coeff_r2: 0.9948
# Epoch 254/6000
#  - 1s - loss: 0.0052 - coeff_r2: 0.9948 - val_loss: 0.0053 - val_coeff_r2: 0.9947
# Epoch 255/6000
#  - 1s - loss: 0.0052 - coeff_r2: 0.9948 - val_loss: 0.0053 - val_coeff_r2: 0.9947
# Epoch 256/6000
#  - 1s - loss: 0.0052 - coeff_r2: 0.9948 - val_loss: 0.0052 - val_coeff_r2: 0.9948
# Epoch 257/6000
#  - 1s - loss: 0.0052 - coeff_r2: 0.9948 - val_loss: 0.0051 - val_coeff_r2: 0.9949
# Epoch 258/6000
#  - 1s - loss: 0.0052 - coeff_r2: 0.9948 - val_loss: 0.0052 - val_coeff_r2: 0.9948
# Epoch 259/6000
#  - 1s - loss: 0.0051 - coeff_r2: 0.9949 - val_loss: 0.0051 - val_coeff_r2: 0.9949
# Epoch 260/6000
#  - 1s - loss: 0.0051 - coeff_r2: 0.9949 - val_loss: 0.0050 - val_coeff_r2: 0.9950
# Epoch 261/6000
#  - 1s - loss: 0.0050 - coeff_r2: 0.9950 - val_loss: 0.0050 - val_coeff_r2: 0.9950
# Epoch 262/6000
#  - 1s - loss: 0.0050 - coeff_r2: 0.9950 - val_loss: 0.0050 - val_coeff_r2: 0.9950
# Epoch 263/6000
#  - 1s - loss: 0.0050 - coeff_r2: 0.9950 - val_loss: 0.0052 - val_coeff_r2: 0.9948
# Epoch 264/6000
#  - 1s - loss: 0.0050 - coeff_r2: 0.9950 - val_loss: 0.0051 - val_coeff_r2: 0.9949
# Epoch 265/6000
#  - 1s - loss: 0.0049 - coeff_r2: 0.9951 - val_loss: 0.0050 - val_coeff_r2: 0.9950
# Epoch 266/6000
#  - 1s - loss: 0.0050 - coeff_r2: 0.9950 - val_loss: 0.0050 - val_coeff_r2: 0.9950
# Epoch 267/6000
#  - 1s - loss: 0.0049 - coeff_r2: 0.9951 - val_loss: 0.0049 - val_coeff_r2: 0.9951
# Epoch 268/6000
#  - 1s - loss: 0.0049 - coeff_r2: 0.9951 - val_loss: 0.0050 - val_coeff_r2: 0.9950
# Epoch 269/6000
#  - 1s - loss: 0.0049 - coeff_r2: 0.9951 - val_loss: 0.0049 - val_coeff_r2: 0.9951
# Epoch 270/6000
#  - 1s - loss: 0.0049 - coeff_r2: 0.9951 - val_loss: 0.0049 - val_coeff_r2: 0.9951
# Epoch 271/6000
#  - 1s - loss: 0.0048 - coeff_r2: 0.9952 - val_loss: 0.0048 - val_coeff_r2: 0.9952
# Epoch 272/6000
#  - 1s - loss: 0.0048 - coeff_r2: 0.9952 - val_loss: 0.0048 - val_coeff_r2: 0.9952
# Epoch 273/6000
#  - 1s - loss: 0.0048 - coeff_r2: 0.9952 - val_loss: 0.0048 - val_coeff_r2: 0.9953
# Epoch 274/6000
#  - 1s - loss: 0.0048 - coeff_r2: 0.9952 - val_loss: 0.0048 - val_coeff_r2: 0.9952
# Epoch 275/6000
#  - 1s - loss: 0.0048 - coeff_r2: 0.9952 - val_loss: 0.0048 - val_coeff_r2: 0.9952
# Epoch 276/6000
#  - 1s - loss: 0.0048 - coeff_r2: 0.9952 - val_loss: 0.0047 - val_coeff_r2: 0.9953
# Epoch 277/6000
#  - 1s - loss: 0.0047 - coeff_r2: 0.9953 - val_loss: 0.0047 - val_coeff_r2: 0.9953
# Epoch 278/6000
#  - 1s - loss: 0.0047 - coeff_r2: 0.9953 - val_loss: 0.0047 - val_coeff_r2: 0.9953
# Epoch 279/6000
#  - 1s - loss: 0.0047 - coeff_r2: 0.9953 - val_loss: 0.0049 - val_coeff_r2: 0.9951
# Epoch 280/6000
#  - 1s - loss: 0.0047 - coeff_r2: 0.9953 - val_loss: 0.0046 - val_coeff_r2: 0.9954
# Epoch 281/6000
#  - 1s - loss: 0.0046 - coeff_r2: 0.9954 - val_loss: 0.0046 - val_coeff_r2: 0.9954
# Epoch 282/6000
#  - 1s - loss: 0.0046 - coeff_r2: 0.9954 - val_loss: 0.0049 - val_coeff_r2: 0.9951
# Epoch 283/6000
#  - 1s - loss: 0.0046 - coeff_r2: 0.9954 - val_loss: 0.0047 - val_coeff_r2: 0.9953
# Epoch 284/6000
#  - 1s - loss: 0.0046 - coeff_r2: 0.9954 - val_loss: 0.0046 - val_coeff_r2: 0.9954
# Epoch 285/6000
#  - 1s - loss: 0.0045 - coeff_r2: 0.9955 - val_loss: 0.0046 - val_coeff_r2: 0.9954
# Epoch 286/6000
#  - 1s - loss: 0.0045 - coeff_r2: 0.9955 - val_loss: 0.0045 - val_coeff_r2: 0.9955
# Epoch 287/6000
#  - 1s - loss: 0.0045 - coeff_r2: 0.9955 - val_loss: 0.0046 - val_coeff_r2: 0.9954
# Epoch 288/6000
#  - 1s - loss: 0.0045 - coeff_r2: 0.9955 - val_loss: 0.0045 - val_coeff_r2: 0.9955
# Epoch 289/6000
#  - 1s - loss: 0.0045 - coeff_r2: 0.9955 - val_loss: 0.0044 - val_coeff_r2: 0.9956
# Epoch 290/6000
#  - 1s - loss: 0.0044 - coeff_r2: 0.9956 - val_loss: 0.0045 - val_coeff_r2: 0.9955
# Epoch 291/6000
#  - 1s - loss: 0.0044 - coeff_r2: 0.9956 - val_loss: 0.0044 - val_coeff_r2: 0.9956
# Epoch 292/6000
#  - 1s - loss: 0.0044 - coeff_r2: 0.9956 - val_loss: 0.0044 - val_coeff_r2: 0.9956
# Epoch 293/6000
#  - 1s - loss: 0.0044 - coeff_r2: 0.9956 - val_loss: 0.0044 - val_coeff_r2: 0.9956
# Epoch 294/6000
#  - 1s - loss: 0.0044 - coeff_r2: 0.9956 - val_loss: 0.0044 - val_coeff_r2: 0.9956
# Epoch 295/6000
#  - 1s - loss: 0.0044 - coeff_r2: 0.9956 - val_loss: 0.0044 - val_coeff_r2: 0.9956
# Epoch 296/6000
#  - 1s - loss: 0.0043 - coeff_r2: 0.9957 - val_loss: 0.0044 - val_coeff_r2: 0.9956
# Epoch 297/6000
#  - 1s - loss: 0.0043 - coeff_r2: 0.9957 - val_loss: 0.0043 - val_coeff_r2: 0.9957
# Epoch 298/6000
#  - 1s - loss: 0.0043 - coeff_r2: 0.9957 - val_loss: 0.0043 - val_coeff_r2: 0.9957
# Epoch 299/6000
#  - 1s - loss: 0.0043 - coeff_r2: 0.9957 - val_loss: 0.0043 - val_coeff_r2: 0.9957
# Epoch 300/6000
#  - 1s - loss: 0.0044 - coeff_r2: 0.9956 - val_loss: 0.0044 - val_coeff_r2: 0.9956
# Epoch 301/6000
#  - 1s - loss: 0.0043 - coeff_r2: 0.9957 - val_loss: 0.0042 - val_coeff_r2: 0.9958
# Epoch 302/6000
#  - 1s - loss: 0.0043 - coeff_r2: 0.9957 - val_loss: 0.0043 - val_coeff_r2: 0.9957
# Epoch 303/6000
#  - 1s - loss: 0.0043 - coeff_r2: 0.9957 - val_loss: 0.0042 - val_coeff_r2: 0.9958
# Epoch 304/6000
#  - 1s - loss: 0.0042 - coeff_r2: 0.9958 - val_loss: 0.0042 - val_coeff_r2: 0.9958
# Epoch 305/6000
#  - 1s - loss: 0.0042 - coeff_r2: 0.9958 - val_loss: 0.0042 - val_coeff_r2: 0.9958
# Epoch 306/6000
#  - 1s - loss: 0.0042 - coeff_r2: 0.9958 - val_loss: 0.0042 - val_coeff_r2: 0.9959
# Epoch 307/6000
#  - 1s - loss: 0.0042 - coeff_r2: 0.9958 - val_loss: 0.0043 - val_coeff_r2: 0.9957
# Epoch 308/6000
#  - 1s - loss: 0.0042 - coeff_r2: 0.9958 - val_loss: 0.0041 - val_coeff_r2: 0.9959
# Epoch 309/6000
#  - 1s - loss: 0.0042 - coeff_r2: 0.9958 - val_loss: 0.0041 - val_coeff_r2: 0.9959
# Epoch 310/6000
#  - 1s - loss: 0.0041 - coeff_r2: 0.9959 - val_loss: 0.0042 - val_coeff_r2: 0.9958
# Epoch 311/6000
#  - 1s - loss: 0.0041 - coeff_r2: 0.9959 - val_loss: 0.0041 - val_coeff_r2: 0.9959
# Epoch 312/6000
#  - 1s - loss: 0.0041 - coeff_r2: 0.9959 - val_loss: 0.0043 - val_coeff_r2: 0.9957
# Epoch 313/6000
#  - 1s - loss: 0.0041 - coeff_r2: 0.9959 - val_loss: 0.0041 - val_coeff_r2: 0.9959
# Epoch 314/6000
#  - 1s - loss: 0.0041 - coeff_r2: 0.9959 - val_loss: 0.0041 - val_coeff_r2: 0.9959
# Epoch 315/6000
#  - 1s - loss: 0.0041 - coeff_r2: 0.9959 - val_loss: 0.0040 - val_coeff_r2: 0.9960
# Epoch 316/6000
#  - 1s - loss: 0.0041 - coeff_r2: 0.9959 - val_loss: 0.0040 - val_coeff_r2: 0.9960
# Epoch 317/6000
#  - 1s - loss: 0.0040 - coeff_r2: 0.9960 - val_loss: 0.0040 - val_coeff_r2: 0.9960
# Epoch 318/6000
#  - 1s - loss: 0.0040 - coeff_r2: 0.9960 - val_loss: 0.0040 - val_coeff_r2: 0.9960
# Epoch 319/6000
#  - 1s - loss: 0.0040 - coeff_r2: 0.9960 - val_loss: 0.0040 - val_coeff_r2: 0.9960
# Epoch 320/6000
#  - 1s - loss: 0.0040 - coeff_r2: 0.9960 - val_loss: 0.0040 - val_coeff_r2: 0.9960
# Epoch 321/6000
#  - 1s - loss: 0.0040 - coeff_r2: 0.9960 - val_loss: 0.0039 - val_coeff_r2: 0.9961
# Epoch 322/6000
#  - 1s - loss: 0.0039 - coeff_r2: 0.9961 - val_loss: 0.0040 - val_coeff_r2: 0.9960
# Epoch 323/6000
#  - 1s - loss: 0.0040 - coeff_r2: 0.9960 - val_loss: 0.0041 - val_coeff_r2: 0.9959
# Epoch 324/6000
#  - 1s - loss: 0.0039 - coeff_r2: 0.9961 - val_loss: 0.0040 - val_coeff_r2: 0.9961
# Epoch 325/6000
#  - 1s - loss: 0.0039 - coeff_r2: 0.9961 - val_loss: 0.0039 - val_coeff_r2: 0.9961
# Epoch 326/6000
#  - 1s - loss: 0.0039 - coeff_r2: 0.9961 - val_loss: 0.0039 - val_coeff_r2: 0.9961
# Epoch 327/6000
#  - 1s - loss: 0.0039 - coeff_r2: 0.9961 - val_loss: 0.0039 - val_coeff_r2: 0.9961
# Epoch 328/6000
#  - 1s - loss: 0.0039 - coeff_r2: 0.9961 - val_loss: 0.0039 - val_coeff_r2: 0.9961
# Epoch 329/6000
#  - 1s - loss: 0.0039 - coeff_r2: 0.9961 - val_loss: 0.0040 - val_coeff_r2: 0.9960
# Epoch 330/6000
#  - 1s - loss: 0.0039 - coeff_r2: 0.9961 - val_loss: 0.0039 - val_coeff_r2: 0.9961
# Epoch 331/6000
#  - 1s - loss: 0.0039 - coeff_r2: 0.9961 - val_loss: 0.0039 - val_coeff_r2: 0.9961
# Epoch 332/6000
#  - 1s - loss: 0.0039 - coeff_r2: 0.9962 - val_loss: 0.0038 - val_coeff_r2: 0.9962
# Epoch 333/6000
#  - 1s - loss: 0.0039 - coeff_r2: 0.9961 - val_loss: 0.0038 - val_coeff_r2: 0.9962
# Epoch 334/6000
#  - 1s - loss: 0.0038 - coeff_r2: 0.9962 - val_loss: 0.0038 - val_coeff_r2: 0.9962
# Epoch 335/6000
#  - 1s - loss: 0.0038 - coeff_r2: 0.9962 - val_loss: 0.0039 - val_coeff_r2: 0.9961
# Epoch 336/6000
#  - 1s - loss: 0.0038 - coeff_r2: 0.9962 - val_loss: 0.0038 - val_coeff_r2: 0.9962
# Epoch 337/6000
#  - 1s - loss: 0.0038 - coeff_r2: 0.9962 - val_loss: 0.0038 - val_coeff_r2: 0.9962
# Epoch 338/6000
#  - 1s - loss: 0.0038 - coeff_r2: 0.9962 - val_loss: 0.0038 - val_coeff_r2: 0.9962
# Epoch 339/6000
#  - 1s - loss: 0.0038 - coeff_r2: 0.9962 - val_loss: 0.0038 - val_coeff_r2: 0.9962
# Epoch 340/6000
#  - 1s - loss: 0.0038 - coeff_r2: 0.9962 - val_loss: 0.0038 - val_coeff_r2: 0.9962
# Epoch 341/6000
#  - 1s - loss: 0.0038 - coeff_r2: 0.9962 - val_loss: 0.0037 - val_coeff_r2: 0.9963
# Epoch 342/6000
#  - 1s - loss: 0.0037 - coeff_r2: 0.9963 - val_loss: 0.0037 - val_coeff_r2: 0.9963
# Epoch 343/6000
#  - 1s - loss: 0.0037 - coeff_r2: 0.9963 - val_loss: 0.0038 - val_coeff_r2: 0.9962
# Epoch 344/6000
#  - 1s - loss: 0.0037 - coeff_r2: 0.9963 - val_loss: 0.0037 - val_coeff_r2: 0.9963
# Epoch 345/6000
#  - 1s - loss: 0.0037 - coeff_r2: 0.9963 - val_loss: 0.0037 - val_coeff_r2: 0.9963
# Epoch 346/6000
#  - 1s - loss: 0.0037 - coeff_r2: 0.9963 - val_loss: 0.0036 - val_coeff_r2: 0.9964
# Epoch 347/6000
#  - 1s - loss: 0.0037 - coeff_r2: 0.9963 - val_loss: 0.0038 - val_coeff_r2: 0.9962
# Epoch 348/6000
#  - 1s - loss: 0.0037 - coeff_r2: 0.9963 - val_loss: 0.0037 - val_coeff_r2: 0.9963
# Epoch 349/6000
#  - 1s - loss: 0.0037 - coeff_r2: 0.9963 - val_loss: 0.0037 - val_coeff_r2: 0.9963
# Epoch 350/6000
#  - 1s - loss: 0.0036 - coeff_r2: 0.9964 - val_loss: 0.0037 - val_coeff_r2: 0.9963
# Epoch 351/6000
#  - 1s - loss: 0.0036 - coeff_r2: 0.9964 - val_loss: 0.0036 - val_coeff_r2: 0.9964
# Epoch 352/6000
#  - 1s - loss: 0.0036 - coeff_r2: 0.9964 - val_loss: 0.0036 - val_coeff_r2: 0.9964
# Epoch 353/6000
#  - 1s - loss: 0.0036 - coeff_r2: 0.9964 - val_loss: 0.0037 - val_coeff_r2: 0.9963
# Epoch 354/6000
#  - 1s - loss: 0.0036 - coeff_r2: 0.9964 - val_loss: 0.0036 - val_coeff_r2: 0.9964
# Epoch 355/6000
#  - 1s - loss: 0.0036 - coeff_r2: 0.9964 - val_loss: 0.0036 - val_coeff_r2: 0.9964
# Epoch 356/6000
#  - 1s - loss: 0.0036 - coeff_r2: 0.9964 - val_loss: 0.0037 - val_coeff_r2: 0.9963
# Epoch 357/6000
#  - 1s - loss: 0.0036 - coeff_r2: 0.9964 - val_loss: 0.0036 - val_coeff_r2: 0.9964
# Epoch 358/6000
#  - 1s - loss: 0.0035 - coeff_r2: 0.9965 - val_loss: 0.0035 - val_coeff_r2: 0.9965
# Epoch 359/6000
#  - 1s - loss: 0.0036 - coeff_r2: 0.9964 - val_loss: 0.0036 - val_coeff_r2: 0.9964
# Epoch 360/6000
#  - 1s - loss: 0.0036 - coeff_r2: 0.9964 - val_loss: 0.0035 - val_coeff_r2: 0.9965
# Epoch 361/6000
#  - 1s - loss: 0.0035 - coeff_r2: 0.9965 - val_loss: 0.0035 - val_coeff_r2: 0.9965
# Epoch 362/6000
#  - 1s - loss: 0.0035 - coeff_r2: 0.9965 - val_loss: 0.0036 - val_coeff_r2: 0.9964
# Epoch 363/6000
#  - 1s - loss: 0.0035 - coeff_r2: 0.9965 - val_loss: 0.0035 - val_coeff_r2: 0.9965
# Epoch 364/6000
#  - 1s - loss: 0.0035 - coeff_r2: 0.9965 - val_loss: 0.0035 - val_coeff_r2: 0.9965
# Epoch 365/6000
#  - 1s - loss: 0.0035 - coeff_r2: 0.9965 - val_loss: 0.0035 - val_coeff_r2: 0.9965
# Epoch 366/6000
#  - 1s - loss: 0.0035 - coeff_r2: 0.9965 - val_loss: 0.0035 - val_coeff_r2: 0.9965
# Epoch 367/6000
#  - 1s - loss: 0.0035 - coeff_r2: 0.9965 - val_loss: 0.0035 - val_coeff_r2: 0.9965
# Epoch 368/6000
#  - 1s - loss: 0.0035 - coeff_r2: 0.9965 - val_loss: 0.0035 - val_coeff_r2: 0.9965
# Epoch 369/6000
#  - 1s - loss: 0.0035 - coeff_r2: 0.9965 - val_loss: 0.0035 - val_coeff_r2: 0.9965
# Epoch 370/6000
#  - 1s - loss: 0.0035 - coeff_r2: 0.9965 - val_loss: 0.0035 - val_coeff_r2: 0.9965
# Epoch 371/6000
#  - 1s - loss: 0.0035 - coeff_r2: 0.9965 - val_loss: 0.0034 - val_coeff_r2: 0.9966
# Epoch 372/6000
#  - 1s - loss: 0.0034 - coeff_r2: 0.9966 - val_loss: 0.0034 - val_coeff_r2: 0.9966
# Epoch 373/6000
#  - 1s - loss: 0.0034 - coeff_r2: 0.9966 - val_loss: 0.0034 - val_coeff_r2: 0.9966
# Epoch 374/6000
#  - 1s - loss: 0.0034 - coeff_r2: 0.9966 - val_loss: 0.0035 - val_coeff_r2: 0.9965
# Epoch 375/6000
#  - 1s - loss: 0.0034 - coeff_r2: 0.9966 - val_loss: 0.0035 - val_coeff_r2: 0.9965
# Epoch 376/6000
#  - 1s - loss: 0.0034 - coeff_r2: 0.9966 - val_loss: 0.0034 - val_coeff_r2: 0.9966
# Epoch 377/6000
#  - 1s - loss: 0.0034 - coeff_r2: 0.9966 - val_loss: 0.0034 - val_coeff_r2: 0.9966
# Epoch 378/6000
#  - 1s - loss: 0.0034 - coeff_r2: 0.9966 - val_loss: 0.0034 - val_coeff_r2: 0.9966
# Epoch 379/6000
#  - 1s - loss: 0.0034 - coeff_r2: 0.9966 - val_loss: 0.0034 - val_coeff_r2: 0.9966
# Epoch 380/6000
#  - 1s - loss: 0.0034 - coeff_r2: 0.9966 - val_loss: 0.0033 - val_coeff_r2: 0.9967
# Epoch 381/6000
#  - 1s - loss: 0.0033 - coeff_r2: 0.9967 - val_loss: 0.0033 - val_coeff_r2: 0.9967
# Epoch 382/6000
#  - 1s - loss: 0.0033 - coeff_r2: 0.9967 - val_loss: 0.0033 - val_coeff_r2: 0.9967
# Epoch 383/6000
#  - 1s - loss: 0.0034 - coeff_r2: 0.9966 - val_loss: 0.0034 - val_coeff_r2: 0.9966
# Epoch 384/6000
#  - 1s - loss: 0.0033 - coeff_r2: 0.9967 - val_loss: 0.0034 - val_coeff_r2: 0.9966
# Epoch 385/6000
#  - 1s - loss: 0.0033 - coeff_r2: 0.9967 - val_loss: 0.0034 - val_coeff_r2: 0.9966
# Epoch 386/6000
#  - 1s - loss: 0.0033 - coeff_r2: 0.9967 - val_loss: 0.0033 - val_coeff_r2: 0.9967
# Epoch 387/6000
#  - 1s - loss: 0.0033 - coeff_r2: 0.9967 - val_loss: 0.0034 - val_coeff_r2: 0.9966
# Epoch 388/6000
#  - 1s - loss: 0.0033 - coeff_r2: 0.9967 - val_loss: 0.0033 - val_coeff_r2: 0.9967
# Epoch 389/6000
#  - 1s - loss: 0.0033 - coeff_r2: 0.9967 - val_loss: 0.0033 - val_coeff_r2: 0.9967
# Epoch 390/6000
#  - 1s - loss: 0.0033 - coeff_r2: 0.9967 - val_loss: 0.0033 - val_coeff_r2: 0.9967
# Epoch 391/6000
#  - 1s - loss: 0.0033 - coeff_r2: 0.9967 - val_loss: 0.0033 - val_coeff_r2: 0.9967
# Epoch 392/6000
#  - 1s - loss: 0.0033 - coeff_r2: 0.9967 - val_loss: 0.0033 - val_coeff_r2: 0.9967
# Epoch 393/6000
#  - 1s - loss: 0.0033 - coeff_r2: 0.9967 - val_loss: 0.0032 - val_coeff_r2: 0.9968
# Epoch 394/6000
#  - 1s - loss: 0.0033 - coeff_r2: 0.9967 - val_loss: 0.0033 - val_coeff_r2: 0.9967
# Epoch 395/6000
#  - 1s - loss: 0.0033 - coeff_r2: 0.9967 - val_loss: 0.0032 - val_coeff_r2: 0.9968
# Epoch 396/6000
#  - 1s - loss: 0.0033 - coeff_r2: 0.9967 - val_loss: 0.0032 - val_coeff_r2: 0.9968
# Epoch 397/6000
#  - 1s - loss: 0.0032 - coeff_r2: 0.9968 - val_loss: 0.0032 - val_coeff_r2: 0.9968
# Epoch 398/6000
#  - 1s - loss: 0.0032 - coeff_r2: 0.9968 - val_loss: 0.0033 - val_coeff_r2: 0.9967
# Epoch 399/6000
#  - 1s - loss: 0.0032 - coeff_r2: 0.9968 - val_loss: 0.0032 - val_coeff_r2: 0.9968
# Epoch 400/6000
#  - 1s - loss: 0.0032 - coeff_r2: 0.9968 - val_loss: 0.0032 - val_coeff_r2: 0.9968
# Epoch 401/6000
#  - 1s - loss: 0.0032 - coeff_r2: 0.9968 - val_loss: 0.0033 - val_coeff_r2: 0.9968
# Epoch 402/6000
#  - 1s - loss: 0.0032 - coeff_r2: 0.9968 - val_loss: 0.0033 - val_coeff_r2: 0.9967
# Epoch 403/6000
#  - 1s - loss: 0.0032 - coeff_r2: 0.9968 - val_loss: 0.0032 - val_coeff_r2: 0.9968
# Epoch 404/6000
#  - 1s - loss: 0.0032 - coeff_r2: 0.9968 - val_loss: 0.0033 - val_coeff_r2: 0.9967
# Epoch 405/6000
#  - 1s - loss: 0.0033 - coeff_r2: 0.9967 - val_loss: 0.0032 - val_coeff_r2: 0.9968
# Epoch 406/6000
#  - 1s - loss: 0.0032 - coeff_r2: 0.9968 - val_loss: 0.0032 - val_coeff_r2: 0.9968
# Epoch 407/6000
#  - 1s - loss: 0.0032 - coeff_r2: 0.9968 - val_loss: 0.0032 - val_coeff_r2: 0.9968
# Epoch 408/6000
#  - 1s - loss: 0.0031 - coeff_r2: 0.9969 - val_loss: 0.0031 - val_coeff_r2: 0.9969
# Epoch 409/6000
#  - 1s - loss: 0.0032 - coeff_r2: 0.9968 - val_loss: 0.0032 - val_coeff_r2: 0.9968
# Epoch 410/6000
#  - 1s - loss: 0.0031 - coeff_r2: 0.9969 - val_loss: 0.0032 - val_coeff_r2: 0.9969
# Epoch 411/6000
#  - 1s - loss: 0.0031 - coeff_r2: 0.9969 - val_loss: 0.0031 - val_coeff_r2: 0.9969
# Epoch 412/6000
#  - 1s - loss: 0.0032 - coeff_r2: 0.9968 - val_loss: 0.0031 - val_coeff_r2: 0.9969
# Epoch 413/6000
#  - 1s - loss: 0.0031 - coeff_r2: 0.9969 - val_loss: 0.0031 - val_coeff_r2: 0.9969
# Epoch 414/6000
#  - 1s - loss: 0.0031 - coeff_r2: 0.9969 - val_loss: 0.0031 - val_coeff_r2: 0.9969
# Epoch 415/6000
#  - 1s - loss: 0.0031 - coeff_r2: 0.9969 - val_loss: 0.0031 - val_coeff_r2: 0.9969
# Epoch 416/6000
#  - 1s - loss: 0.0031 - coeff_r2: 0.9969 - val_loss: 0.0031 - val_coeff_r2: 0.9969
# Epoch 417/6000
#  - 1s - loss: 0.0031 - coeff_r2: 0.9969 - val_loss: 0.0031 - val_coeff_r2: 0.9969
# Epoch 418/6000
#  - 1s - loss: 0.0031 - coeff_r2: 0.9969 - val_loss: 0.0031 - val_coeff_r2: 0.9969
# Epoch 419/6000
#  - 1s - loss: 0.0031 - coeff_r2: 0.9969 - val_loss: 0.0031 - val_coeff_r2: 0.9969
# Epoch 420/6000
#  - 1s - loss: 0.0031 - coeff_r2: 0.9969 - val_loss: 0.0030 - val_coeff_r2: 0.9970
# Epoch 421/6000
#  - 1s - loss: 0.0031 - coeff_r2: 0.9969 - val_loss: 0.0031 - val_coeff_r2: 0.9969
# Epoch 422/6000
#  - 1s - loss: 0.0031 - coeff_r2: 0.9969 - val_loss: 0.0031 - val_coeff_r2: 0.9969
# Epoch 423/6000
#  - 1s - loss: 0.0030 - coeff_r2: 0.9970 - val_loss: 0.0031 - val_coeff_r2: 0.9969
# Epoch 424/6000
#  - 1s - loss: 0.0031 - coeff_r2: 0.9969 - val_loss: 0.0030 - val_coeff_r2: 0.9970
# Epoch 425/6000
#  - 1s - loss: 0.0031 - coeff_r2: 0.9969 - val_loss: 0.0031 - val_coeff_r2: 0.9969
# Epoch 426/6000
#  - 1s - loss: 0.0031 - coeff_r2: 0.9969 - val_loss: 0.0031 - val_coeff_r2: 0.9969
# Epoch 427/6000
#  - 1s - loss: 0.0030 - coeff_r2: 0.9970 - val_loss: 0.0031 - val_coeff_r2: 0.9969
# Epoch 428/6000
#  - 1s - loss: 0.0030 - coeff_r2: 0.9970 - val_loss: 0.0030 - val_coeff_r2: 0.9970
# Epoch 429/6000
#  - 1s - loss: 0.0030 - coeff_r2: 0.9970 - val_loss: 0.0030 - val_coeff_r2: 0.9970
# Epoch 430/6000
#  - 1s - loss: 0.0030 - coeff_r2: 0.9970 - val_loss: 0.0031 - val_coeff_r2: 0.9969
# Epoch 431/6000
#  - 1s - loss: 0.0030 - coeff_r2: 0.9970 - val_loss: 0.0031 - val_coeff_r2: 0.9969
# Epoch 432/6000
#  - 1s - loss: 0.0030 - coeff_r2: 0.9970 - val_loss: 0.0030 - val_coeff_r2: 0.9970
# Epoch 433/6000
#  - 1s - loss: 0.0030 - coeff_r2: 0.9970 - val_loss: 0.0030 - val_coeff_r2: 0.9970
# Epoch 434/6000
#  - 1s - loss: 0.0030 - coeff_r2: 0.9970 - val_loss: 0.0030 - val_coeff_r2: 0.9970
# Epoch 435/6000
#  - 1s - loss: 0.0030 - coeff_r2: 0.9970 - val_loss: 0.0030 - val_coeff_r2: 0.9970
# Epoch 436/6000
#  - 1s - loss: 0.0030 - coeff_r2: 0.9970 - val_loss: 0.0030 - val_coeff_r2: 0.9970
# Epoch 437/6000
#  - 1s - loss: 0.0030 - coeff_r2: 0.9970 - val_loss: 0.0030 - val_coeff_r2: 0.9971
# Epoch 438/6000
#  - 1s - loss: 0.0030 - coeff_r2: 0.9970 - val_loss: 0.0029 - val_coeff_r2: 0.9971
# Epoch 439/6000
#  - 1s - loss: 0.0030 - coeff_r2: 0.9970 - val_loss: 0.0030 - val_coeff_r2: 0.9970
# Epoch 440/6000
#  - 1s - loss: 0.0030 - coeff_r2: 0.9970 - val_loss: 0.0030 - val_coeff_r2: 0.9970
# Epoch 441/6000
#  - 1s - loss: 0.0030 - coeff_r2: 0.9970 - val_loss: 0.0029 - val_coeff_r2: 0.9971
# Epoch 442/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0029 - val_coeff_r2: 0.9971
# Epoch 443/6000
#  - 1s - loss: 0.0030 - coeff_r2: 0.9970 - val_loss: 0.0030 - val_coeff_r2: 0.9970
# Epoch 444/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0029 - val_coeff_r2: 0.9971
# Epoch 445/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0029 - val_coeff_r2: 0.9971
# Epoch 446/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0031 - val_coeff_r2: 0.9969
# Epoch 447/6000
#  - 1s - loss: 0.0030 - coeff_r2: 0.9970 - val_loss: 0.0029 - val_coeff_r2: 0.9971
# Epoch 448/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0030 - val_coeff_r2: 0.9970
# Epoch 449/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0030 - val_coeff_r2: 0.9970
# Epoch 450/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0029 - val_coeff_r2: 0.9971
# Epoch 451/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0029 - val_coeff_r2: 0.9972
# Epoch 452/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0030 - val_coeff_r2: 0.9970
# Epoch 453/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0029 - val_coeff_r2: 0.9971
# Epoch 454/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0029 - val_coeff_r2: 0.9971
# Epoch 455/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0029 - val_coeff_r2: 0.9971
# Epoch 456/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 457/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0029 - val_coeff_r2: 0.9971
# Epoch 458/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0029 - val_coeff_r2: 0.9971
# Epoch 459/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 460/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0029 - val_coeff_r2: 0.9971
# Epoch 461/6000
#  - 1s - loss: 0.0028 - coeff_r2: 0.9972 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 462/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0029 - val_coeff_r2: 0.9971
# Epoch 463/6000
#  - 1s - loss: 0.0028 - coeff_r2: 0.9972 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 464/6000
#  - 1s - loss: 0.0028 - coeff_r2: 0.9972 - val_loss: 0.0029 - val_coeff_r2: 0.9971
# Epoch 465/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 466/6000
#  - 1s - loss: 0.0028 - coeff_r2: 0.9972 - val_loss: 0.0029 - val_coeff_r2: 0.9971
# Epoch 467/6000
#  - 1s - loss: 0.0029 - coeff_r2: 0.9971 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 468/6000
#  - 1s - loss: 0.0028 - coeff_r2: 0.9972 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 469/6000
#  - 1s - loss: 0.0028 - coeff_r2: 0.9972 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 470/6000
#  - 1s - loss: 0.0028 - coeff_r2: 0.9972 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 471/6000
#  - 1s - loss: 0.0028 - coeff_r2: 0.9972 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 472/6000
#  - 1s - loss: 0.0028 - coeff_r2: 0.9972 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 473/6000
#  - 1s - loss: 0.0028 - coeff_r2: 0.9972 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 474/6000
#  - 1s - loss: 0.0028 - coeff_r2: 0.9972 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 475/6000
#  - 1s - loss: 0.0028 - coeff_r2: 0.9972 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 476/6000
#  - 1s - loss: 0.0028 - coeff_r2: 0.9972 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 477/6000
#  - 1s - loss: 0.0028 - coeff_r2: 0.9972 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 478/6000
#  - 1s - loss: 0.0028 - coeff_r2: 0.9972 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 479/6000
#  - 1s - loss: 0.0028 - coeff_r2: 0.9972 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 480/6000
#  - 1s - loss: 0.0028 - coeff_r2: 0.9972 - val_loss: 0.0027 - val_coeff_r2: 0.9973
# Epoch 481/6000
#  - 1s - loss: 0.0028 - coeff_r2: 0.9972 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 482/6000
#  - 1s - loss: 0.0027 - coeff_r2: 0.9973 - val_loss: 0.0028 - val_coeff_r2: 0.9972
# Epoch 483/6000
#  - 1s - loss: 0.0027 - coeff_r2: 0.9973 - val_loss: 0.0027 - val_coeff_r2: 0.9973
# Epoch 484/6000
