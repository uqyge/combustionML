# %%
from keras.models import load_model
import pandas as pd

# %%
model = load_model('FPV_ANN_tabulated_Standard.H5')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 3)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 50)           200         input_1[0][0]
# __________________________________________________________________________________________________
# res1a_branch2a (Dense)          (None, 150)          7650        dense_1[0][0]
# __________________________________________________________________________________________________
# res1a_branch2a_0 (Dense)        (None, 150)          7650        dense_1[0][0]
# __________________________________________________________________________________________________
# res1a_branch2a_1 (Dense)        (None, 150)          7650        dense_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 150)          0           res1a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 150)          0           res1a_branch2a_0[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 150)          0           res1a_branch2a_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 450)          0           activation_1[0][0]
#                                                                  activation_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# res1a_branch2b (Dense)          (None, 50)           22550       concatenate_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 50)           0           res1a_branch2b[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 50)           0           add_1[0][0]
# __________________________________________________________________________________________________
# res1b_branch2a (Dense)          (None, 150)          7650        activation_4[0][0]
# __________________________________________________________________________________________________
# res1b_branch2a_0 (Dense)        (None, 150)          7650        activation_4[0][0]
# __________________________________________________________________________________________________
# res1b_branch2a_1 (Dense)        (None, 150)          7650        activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 150)          0           res1b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 150)          0           res1b_branch2a_0[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 150)          0           res1b_branch2a_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 450)          0           activation_5[0][0]
#                                                                  activation_6[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# res1b_branch2b (Dense)          (None, 50)           22550       concatenate_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 50)           0           res1b_branch2b[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 50)           0           add_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           510         activation_8[0][0]
# ==================================================================================================
# Total params: 91,710
# Trainable params: 91,710
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /home/eg/anaconda3/envs/my_dev/lib/python3.6/site-packages/keras/engine/saving.py:327: UserWarning: Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
#   warnings.warn('Error in loading the saved optimizer '

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler


class data_scaler(object):
    def __init__(self):
        self.norm = None
        self.norm_1 = None
        self.std = None
        self.case = None
        self.scale = 1
        self.bias = 1e-20
#         self.bias = 1


        self.switcher = {
            'min_std': 'min_std',
            'std2': 'std2',
            'std_min':'std_min',
            'min': 'min',
            'no':'no',
            'log': 'log',
            'log_min':'log_min',
            'log2': 'log2',
            'tan': 'tan'
        }

    def fit_transform(self, input_data, case):
        self.case = case
        if self.switcher.get(self.case) == 'min_std':
            self.norm = MinMaxScaler()
            self.std = StandardScaler()
            out = self.norm.fit_transform(input_data)
            out = self.std.fit_transform(out)

        if self.switcher.get(self.case) == 'std2':
            self.std = StandardScaler()
            out = self.std.fit_transform(input_data)

        if self.switcher.get(self.case) == 'std_min':
            self.norm = MinMaxScaler()
            self.std = StandardScaler()
            out = self.std.fit_transform(input_data)
            out = self.norm.fit_transform(out)

        if self.switcher.get(self.case) == 'min':
            self.norm = MinMaxScaler()
            out = self.norm.fit_transform(input_data)

        if self.switcher.get(self.case) == 'no':
            self.norm = MinMaxScaler()
            self.std = StandardScaler()
            out = input_data

        if self.switcher.get(self.case) == 'log':
            out = - np.log(np.asarray(input_data / self.scale) + self.bias)
            self.std = StandardScaler()
            out = self.std.fit_transform(out)

        if self.switcher.get(self.case) == 'log_min':
            out = - np.log(np.asarray(input_data / self.scale) + self.bias)
            self.norm = MinMaxScaler()
            out = self.norm.fit_transform(out)

        if self.switcher.get(self.case) == 'log2':
            self.norm = MinMaxScaler()
            self.norm_1 = MinMaxScaler()
            out = self.norm.fit_transform(input_data)
            out = np.log(np.asarray(out) + self.bias)
            out = self.norm_1.fit_transform(out)

        if self.switcher.get(self.case) == 'tan':
            self.norm = MaxAbsScaler()
            self.std = StandardScaler()
            out = self.std.fit_transform(input_data)
            out = self.norm.fit_transform(out)
            out = np.tan(out / (2 * np.pi + self.bias))

        return out

    def transform(self, input_data):
        if self.switcher.get(self.case) == 'min_std':
            out = self.norm.transform(input_data)
            out = self.std.transform(out)

        if self.switcher.get(self.case) == 'std2':
            out = self.std.transform(input_data)

        if self.switcher.get(self.case) == 'std_min':
            out = self.std.transform(input_data)
            out = self.norm.transform(out)

        if self.switcher.get(self.case) == 'min':
            out = self.norm.transform(input_data)

        if self.switcher.get(self.case) == 'no':
            out = input_data

        if self.switcher.get(self.case) == 'log':
            out = - np.log(np.asarray(input_data / self.scale) + self.bias)
            out = self.std.transform(out)

        if self.switcher.get(self.case) == 'log_min':
            out = - np.log(np.asarray(input_data / self.scale) + self.bias)
            out = self.norm.transform(out)

        if self.switcher.get(self.case) == 'log2':
            out = self.norm.transform(input_data)
            out = np.log(np.asarray(out) + self.bias)
            out = self.norm_1.transform(out)

        if self.switcher.get(self.case) == 'tan':
            out = self.std.transform(input_data)
            out = self.norm.transform(out)
            out = np.tan(out / (2 * np.pi + self.bias))

        return out

    def inverse_transform(self, input_data):

        if self.switcher.get(self.case) == 'min_std':
            out = self.std.inverse_transform(input_data)
            out = self.norm.inverse_transform(out)

        if self.switcher.get(self.case) == 'std2':
            out = self.std.inverse_transform(input_data)

        if self.switcher.get(self.case) == 'std_min':
            out = self.norm.inverse_transform(input_data)
            out = self.std.inverse_transform(out)

        if self.switcher.get(self.case) == 'min':
            out = self.norm.inverse_transform(input_data)

        if self.switcher.get(self.case) == 'no':
            out = input_data

        if self.switcher.get(self.case) == 'log':
            out = self.std.inverse_transform(input_data)
            out = (np.exp(-out) - self.bias) * self.scale

        if self.switcher.get(self.case) == 'log_min':
            out = self.norm.inverse_transform(input_data)
            out = (np.exp(-out) - self.bias) * self.scale

        if self.switcher.get(self.case) == 'log2':
            out = self.norm_1.inverse_transform(input_data)
            out = np.exp(out) - self.bias
            out = self.norm.inverse_transform(out)

        if self.switcher.get(self.case) == 'tan':
            out = (2 * np.pi + self.bias) * np.arctan(input_data)
            out = self.norm.inverse_transform(out)
            out = self.std.inverse_transform(out)

        return out
      

def read_h5_data(fileName, input_features, labels):
    df = pd.read_hdf(fileName)
#     df = df[df['f']<0.45]
    
    input_df=df[input_features]
    in_scaler = data_scaler()
    input_np = in_scaler.fit_transform(input_df.values,'std2')

    label_df=df[labels].clip(0)
#     if 'PVs' in labels:
#       label_df['PVs']=np.log(label_df['PVs']+1)
    out_scaler = data_scaler()
    label_np = out_scaler.fit_transform(label_df.values,'std2')

    return input_np, label_np, df, in_scaler, out_scaler

# %%
labels = ['CH4','O2','H2O','CO','CO2','T','PVs','psi','mu','alpha']
# labels = ['T','PVs']
# labels = ['T','CH4','O2','CO2','CO','H2O','H2','OH','psi']
# labels = ['CH2OH','HNCO','CH3OH', 'CH2CHO', 'CH2O', 'C3H8', 'HNO', 'NH2', 'HCN']

# labels = np.random.choice(col_labels,20,replace=False).tolist()
# labels.append('PVs')

# labels = col_labels

print(labels)

input_features=['f','zeta','pv']

# read in the data
x_input, y_label, df, in_scaler, out_scaler = read_h5_data('./data/tables_of_fgm.h5',input_features=input_features, labels = labels)
# Out:
# ['CH4', 'O2', 'H2O', 'CO', 'CO2', 'T', 'PVs', 'psi', 'mu', 'alpha']

# %%
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_input,y_label, test_size=0.01)

x_test_df = pd.DataFrame(in_scaler.inverse_transform(x_test),columns=input_features)
y_test_df = pd.DataFrame(out_scaler.inverse_transform(y_test),columns=labels)

predict_val = model.predict(x_test,batch_size=1024*8)
predict_df = pd.DataFrame(out_scaler.inverse_transform(predict_val), columns=labels)

test_data=pd.concat([x_test_df,y_test_df],axis=1)
pred_data=pd.concat([x_test_df,predict_df],axis=1)

# !rm sim_check.h5
test_data.to_hdf('sim_check.h5',key='test')
pred_data.to_hdf('sim_check.h5',key='pred')

df_test=pd.read_hdf('sim_check.h5',key='test')
df_pred=pd.read_hdf('sim_check.h5',key='pred')

zeta_level=list(set(df_test['zeta']))
zeta_level.sort()


res_sum=pd.DataFrame()
r2s=[]
r2s_i=[]

names=[]
maxs_0=[]
maxs_9=[]

for r2,name in zip(r2_score(df_test,df_pred,multioutput='raw_values'),df_test.columns):
  names.append(name)
  r2s.append(r2)
  maxs_0.append(df_test[df_test['zeta']==zeta_level[0]][name].max())
  maxs_9.append(df_test[df_test['zeta']==zeta_level[8]][name].max())
  for i in zeta_level:
    r2s_i.append(r2_score(df_pred[df_pred['zeta']==i][name],
                          df_test[df_test['zeta']==i][name]))

res_sum['name']=names
# res_sum['max_0']=maxs_0
# res_sum['max_9']=maxs_9
res_sum['z_scale']=[m_9/(m_0+1e-20) for m_9,m_0 in zip(maxs_9,maxs_0)]
# res_sum['r2']=r2s


tmp=np.asarray(r2s_i).reshape(-1,10)
for idx,z in enumerate(zeta_level):
  res_sum['r2s_'+str(z)]=tmp[:,idx]

res_sum[3:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-cd631cebf75f> in <module>
#       7 y_test_df = pd.DataFrame(out_scaler.inverse_transform(y_test),columns=labels)
#       8
# ----> 9 predict_val = model.predict(x_test,batch_size=1024*8)
#      10 predict_df = pd.DataFrame(out_scaler.inverse_transform(predict_val), columns=labels)
#      11
#
# NameError: name 'model' is not defined

# %%
#@title import plotly
import plotly.plotly as py
import numpy as np
from plotly.offline import init_notebook_mode, iplot
# from plotly.graph_objs import Contours, Histogram2dContour, Marker, Scatter
import plotly.graph_objs as go

def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-1.5.1.min.js?noext',
            },
          });
        </script>
        '''))

# %%
#@title Default title text
# species = np.random.choice(labels)
species = 'PVs' #@param {type:"string"}
z_level =  8 #@param {type:"integer"}

# configure_plotly_browser_state()
# init_notebook_mode(connected=False)

from sklearn.metrics import r2_score


df_t=df_test[df_test['zeta']==zeta_level[z_level]].sample(frac=1)
# df_p=df_pred.loc[df_pred['zeta']==zeta_level[1]].sample(frac=0.1)
df_p=df_pred.loc[df_t.index]
error=df_p[species]-df_t[species]
r2=round(r2_score(df_p[species],df_t[species]),4)

print(species,'r2:',r2,'max:',df_t[species].max())

fig_db = {
    'data': [       
        {'name':'test data from table',
         'x': df_t['f'],
         'y': df_t['pv'],
         'z': df_t[species],
         'type':'scatter3d', 
        'mode': 'markers',
          'marker':{
              'size':1
          }
        },
        {'name':'prediction from neural networks',
         'x': df_p['f'],
         'y': df_p['pv'],
         'z': df_p[species],
         'type':'scatter3d', 
        'mode': 'markers',
          'marker':{
              'size':1
          },
        },
        {'name':'error in difference',
         'x': df_p['f'],
         'y': df_p['pv'],
         'z': error,
         'type':'scatter3d', 
         'mode': 'markers',
          'marker':{
              'size':1
          },
         }       
    ],
    'layout': {
        'scene':{
            'xaxis': {'title':'mixture fraction'},
            'yaxis': {'title':'progress variable'},
            'zaxis': {'title': species+'_r2:'+str(r2)}
                 }
    }
}
# iplot(fig_db, filename='multiple-scatter')
iplot(fig_db)
# Out:
# PVs r2: 0.9577 max: 608.7450000000001

# %%
df_pred['T'].min()
# Out:
# 284.9543

# %%
df_pred['T'].max()
# Out:
# 2101.1196

# %%
model.predict(x_train)
# Out:
# array([[ 0.6769774 , -1.1170313 ,  0.50836015, ..., -0.9276614 ,
#          0.4950804 , -0.9276611 ],
#        [ 1.6874259 , -1.2149312 , -0.9262146 , ...,  0.41739053,
#         -1.0229086 ,  0.41741043],
#        [ 0.23371792, -0.88185877,  0.915386  , ..., -1.0923101 ,
#          0.91602397, -1.0923117 ],
#        ...,
#        [ 0.34691727,  0.22279888, -0.94371104, ...,  1.262028  ,
#         -1.1375837 ,  1.2620499 ],
#        [-0.15659708,  0.20444524,  0.06954801, ..., -0.38524592,
#          0.09834945, -0.38525063],
#        [-0.11805761,  0.13514513,  0.11049533, ..., -0.44230604,
#          0.14391035, -0.44231075]], dtype=float32)

# %%
predict_val = model.predict(x_train,batch_size=1024*8)
predict_df = pd.DataFrame(out_scaler.inverse_transform(predict_val), columns=labels)

# %%
predict_df.head()
# Out:
#         CH4        O2       H2O        CO       CO2           T         PVs  \
# 0  0.681832  0.008423  0.036931  0.030295  0.012096  651.976379    3.364936
# 1  0.978311  0.002118  0.001857  0.001291  0.000442  317.841675   -0.338540
# 2  0.551773  0.023569  0.046882  0.035836  0.014686  765.586426  271.924133
# 3  0.823753  0.032459  0.006350  0.003573  0.000988  360.182251   -1.019585
# 4  0.065271  0.213918  0.003339  0.001032  0.000367  335.565613    0.117439
#
#         psi        mu     alpha
# 0  0.000029  0.000034  0.000003
# 1  0.000047  0.000019  0.000006
# 2  0.000027  0.000038  0.000003
# 3  0.000044  0.000022  0.000006
# 4  0.000069  0.000020  0.000010

# %%
predict_df['T'].min()
# Out:
# 283.84952

# %%
predict_df['T'].max()
# Out:
# 2215.8882

# %%
df['T'].min()
# Out:
# 283.937

# %%
df['T'].max()
# Out:
# 2230.45

# %%
from keras.models import Model
from keras.layers import Dense, Input, Dropout
from keras.callbacks import ModelCheckpoint


n_neuron = 5
# %%
print('set up student network')
# ANN parameters
dim_input = x_train.shape[1]
dim_label = y_train.shape[1]

batch_norm = False

# This returns a tensor
inputs = Input(shape=(dim_input,),name='input_1')

# a layer instance is callable on a tensor, and returns a tensor
x = Dense(n_neuron, activation='relu')(inputs)
x = Dense(n_neuron, activation='relu')(x)
# x = Dropout(0.1)(x)
predictions = Dense(dim_label, activation='linear', name='output_1')(x)

student_model = Model(inputs=inputs, outputs=predictions)
student_model.summary()
# Out:
# set up student network
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 20
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 30
# _________________________________________________________________
# output_1 (Dense)             (None, 10)                60
# =================================================================
# Total params: 110
# Trainable params: 110
# Non-trainable params: 0
# _________________________________________________________________

# %%
student_model.save('student.h5')

# %%
eg = pd.read_hdf('student.h5','model_weights')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-411f4d32dac3> in <module>
# ----> 1 eg = pd.read_hdf('student.h5','model_weights')
#
# ~/anaconda3/envs/my_dev/lib/python3.6/site-packages/pandas/io/pytables.py in read_hdf(path_or_buf, key, mode, **kwargs)
#     392                                      'contains multiple datasets.')
#     393             key = candidate_only_group._v_pathname
# --> 394         return store.select(key, auto_close=auto_close, **kwargs)
#     395     except:
#     396         # if there is an error, close the store
#
# ~/anaconda3/envs/my_dev/lib/python3.6/site-packages/pandas/io/pytables.py in select(self, key, where, start, stop, columns, iterator, chunksize, auto_close, **kwargs)
#     725         # create the storer and axes
#     726         where = _ensure_term(where, scope_level=1)
# --> 727         s = self._create_storer(group)
#     728         s.infer_axes()
#     729
#
# ~/anaconda3/envs/my_dev/lib/python3.6/site-packages/pandas/io/pytables.py in _create_storer(self, group, format, value, append, **kwargs)
#    1254                 else:
#    1255                     raise TypeError(
# -> 1256                         "cannot create a storer if the object is not existing "
#    1257                         "nor a value are passed")
#    1258             else:
#
# TypeError: cannot create a storer if the object is not existing nor a value are passed

# %%
import keras.backend as K
from keras.callbacks import LearningRateScheduler
import math

def cubic_loss(y_true, y_pred):
    return K.mean(K.square(y_true - y_pred)*K.abs(y_true - y_pred), axis=-1)

def coeff_r2(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square( y_true-y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

  
def step_decay(epoch):
   initial_lrate = 0.001
   drop = 0.5
   epochs_drop = 200.0
   lrate = initial_lrate * math.pow(drop,math.floor((1+epoch)/epochs_drop))
   return lrate
  
lrate = LearningRateScheduler(step_decay)

# %%
from keras import optimizers
batch_size = 1024*32
epochs = 2000
vsplit = 0.1

loss_type='mse'

adam_op = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999,epsilon=1e-8, decay=0.0, amsgrad=True)

student_model.compile(loss=loss_type, optimizer=adam_op, metrics=[coeff_r2])
# model.compile(loss=cubic_loss, optimizer=adam_op, metrics=['accuracy'])

# checkpoint (save the best model based validate loss)
# !mkdir ./tmp
filepath = "./tmp/student_weights.best.cntk.hdf5"

checkpoint = ModelCheckpoint(filepath,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True,
                             mode='min',
                             period=20)

# callbacks_list = [checkpoint]
callbacks_list = [lrate]

x_train_teacher = x_train
y_train_teacher = model.predict(x_train, batch_size=1024*8)
# fit the model
history = student_model.fit(
    x_train_teacher, y_train_teacher,
    epochs=epochs,
    batch_size=batch_size,
    validation_split=vsplit,
    verbose=2,
#     callbacks=callbacks_list,
    shuffle=True)
# Out:
# mkdir: cannot create directory ‘./tmp’: File exists
# Train on 2236418 samples, validate on 248491 samples
# Epoch 1/2000
#  - 2s - loss: 0.0023 - coeff_r2: 0.9977 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 2/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 3/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 4/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 5/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 6/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 7/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 8/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 9/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 10/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 11/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 12/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 13/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 14/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 15/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 16/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 17/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9986
# Epoch 18/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 19/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 20/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 21/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0014 - val_coeff_r2: 0.9986
# Epoch 22/2000
#  - 1s - loss: 0.0014 - coeff_r2: 0.9986 - val_loss: 0.0014 - val_coeff_r2: 0.9986
# Epoch 23/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 24/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 25/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 26/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 27/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0014 - val_coeff_r2: 0.9986
# Epoch 28/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0015 - val_coeff_r2: 0.9985
# Epoch 29/2000
#  - 1s - loss: 0.0014 - coeff_r2: 0.9986 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 30/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 31/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 32/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0014 - val_coeff_r2: 0.9986
# Epoch 33/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 34/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 35/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 36/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 37/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 38/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 39/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 40/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 41/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 42/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 43/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 44/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 45/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 46/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 47/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 48/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 49/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 50/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 51/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 52/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 53/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 54/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 55/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9986
# Epoch 56/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 57/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 58/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 59/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 60/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 61/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 62/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 63/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 64/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 65/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 66/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 67/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 68/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 69/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 70/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0012 - val_coeff_r2: 0.9987
# Epoch 71/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 72/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0012 - val_coeff_r2: 0.9987
# Epoch 73/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 74/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 75/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 76/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 77/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 78/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 79/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 80/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 81/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 82/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 83/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 84/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 85/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 86/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 87/2000
#  - 1s - loss: 0.0013 - coeff_r2: 0.9987 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 88/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 89/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 90/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 91/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 92/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 93/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 94/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 95/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 96/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 97/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 98/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 99/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 100/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 101/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 102/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 103/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 104/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 105/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 106/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 107/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 108/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 109/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 110/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 111/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 112/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 113/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 114/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 115/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 116/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 117/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 118/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 119/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 120/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 121/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 122/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 123/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 124/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 125/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 126/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 127/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 128/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 129/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 130/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0011 - val_coeff_r2: 0.9988
# Epoch 131/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0011 - val_coeff_r2: 0.9988
# Epoch 132/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 133/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 134/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0013 - val_coeff_r2: 0.9987
# Epoch 135/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 136/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 137/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 138/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 139/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 140/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 141/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0011 - val_coeff_r2: 0.9988
# Epoch 142/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0011 - val_coeff_r2: 0.9988
# Epoch 143/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 144/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 145/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 146/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 147/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 148/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0011 - val_coeff_r2: 0.9988
# Epoch 149/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 150/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 151/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 152/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 153/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 154/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 155/2000
#  - 1s - loss: 0.0011 - coeff_r2: 0.9989 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 156/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0011 - val_coeff_r2: 0.9988
# Epoch 157/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 158/2000
#  - 1s - loss: 0.0011 - coeff_r2: 0.9989 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 159/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 160/2000
#  - 1s - loss: 0.0011 - coeff_r2: 0.9989 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 161/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 162/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 163/2000
#  - 1s - loss: 0.0011 - coeff_r2: 0.9989 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 164/2000
#  - 1s - loss: 0.0011 - coeff_r2: 0.9989 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 165/2000
#  - 1s - loss: 0.0011 - coeff_r2: 0.9989 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 166/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9989 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 167/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 168/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 169/2000
#  - 1s - loss: 0.0011 - coeff_r2: 0.9989 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 170/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 171/2000
#  - 1s - loss: 0.0011 - coeff_r2: 0.9989 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 172/2000
#  - 1s - loss: 0.0011 - coeff_r2: 0.9989 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 173/2000
#  - 1s - loss: 0.0011 - coeff_r2: 0.9989 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 174/2000
#  - 1s - loss: 0.0011 - coeff_r2: 0.9989 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 175/2000
#  - 1s - loss: 0.0011 - coeff_r2: 0.9989 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 176/2000
#  - 1s - loss: 0.0011 - coeff_r2: 0.9989 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 177/2000
#  - 1s - loss: 0.0011 - coeff_r2: 0.9989 - val_loss: 0.0011 - val_coeff_r2: 0.9988
# Epoch 178/2000
#  - 1s - loss: 0.0012 - coeff_r2: 0.9988 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 179/2000
#  - 1s - loss: 0.0011 - coeff_r2: 0.9989 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 180/2000
#  - 1s - loss: 0.0011 - coeff_r2: 0.9989 - val_loss: 0.0012 - val_coeff_r2: 0.9988
# Epoch 181/2000
#  - 1s - loss: 0.0011 - coeff_r2: 0.9989 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 182/2000
#  - 1s - loss: 0.0011 - coeff_r2: 0.9989 - val_loss: 0.0011 - val_coeff_r2: 0.9989
# Epoch 183/2000
#  - 1s - loss: 0.0011 - coeff_r2: 0.9989 - val_loss: 0.0011 - val_coeff_r2: 0.
# Epoch 434/2000
#  - 1s - loss: 9.5501e-04 - coeff_r2: 0.9990 - val_loss: 9.3824e-04 - val_coeff_r2: 0.9991
# Epoch 435/2000
#  - 1s - loss: 9.5273e-04 - coeff_r2: 0.9990 - val_loss: 9.6389e-04 - val_coeff_r2: 0.9990
# Epoch 436/2000
#  - 1s - loss: 9.3968e-04 - coeff_r2: 0.9991 - val_loss: 9.5325e-04 - val_coeff_r2: 0.9990
# Epoch 437/2000
#  - 1s - loss: 9.4449e-04 - coeff_r2: 0.9991 - val_loss: 9.6143e-04 - val_coeff_r2: 0.9990
# Epoch 438/2000
#  - 1s - loss: 9.5165e-04 - coeff_r2: 0.9990 - val_loss: 9.2908e-04 - val_coeff_r2: 0.9991
# Epoch 439/2000
#  - 1s - loss: 9.4323e-04 - coeff_r2: 0.9991 - val_loss: 9.5831e-04 - val_coeff_r2: 0.9990
# Epoch 440/2000
#  - 1s - loss: 9.3588e-04 - coeff_r2: 0.9991 - val_loss: 9.3495e-04 - val_coeff_r2: 0.9991
# Epoch 441/2000
#  - 1s - loss: 9.4634e-04 - coeff_r2: 0.9991 - val_loss: 9.4821e-04 - val_coeff_r2: 0.9990
# Epoch 442/2000
#  - 1s - loss: 9.5079e-04 - coeff_r2: 0.9991 - val_loss: 9.3461e-04 - val_coeff_r2: 0.9991
# Epoch 443/2000
#  - 1s - loss: 9.4166e-04 - coeff_r2: 0.9991 - val_loss: 9.4063e-04 - val_coeff_r2: 0.9991
# Epoch 444/2000
#  - 1s - loss: 9.3339e-04 - coeff_r2: 0.9991 - val_loss: 9.5958e-04 - val_coeff_r2: 0.9990
# Epoch 445/2000
#  - 1s - loss: 9.5183e-04 - coeff_r2: 0.9990 - val_loss: 9.2640e-04 - val_coeff_r2: 0.9991
# Epoch 446/2000
#  - 1s - loss: 9.3681e-04 - coeff_r2: 0.9991 - val_loss: 9.8580e-04 - val_coeff_r2: 0.9990
# Epoch 447/2000
#  - 1s - loss: 9.3931e-04 - coeff_r2: 0.9991 - val_loss: 9.5292e-04 - val_coeff_r2: 0.9990
# Epoch 448/2000
#  - 1s - loss: 9.5813e-04 - coeff_r2: 0.9990 - val_loss: 9.3505e-04 - val_coeff_r2: 0.9991
# Epoch 449/2000
#  - 1s - loss: 9.4319e-04 - coeff_r2: 0.9991 - val_loss: 9.3699e-04 - val_coeff_r2: 0.9991
# Epoch 450/2000
#  - 1s - loss: 9.2976e-04 - coeff_r2: 0.9991 - val_loss: 9.3824e-04 - val_coeff_r2: 0.9991
# Epoch 451/2000
#  - 1s - loss: 9.4923e-04 - coeff_r2: 0.9991 - val_loss: 9.2660e-04 - val_coeff_r2: 0.9991
# Epoch 452/2000
#  - 1s - loss: 9.4554e-04 - coeff_r2: 0.9991 - val_loss: 9.4486e-04 - val_coeff_r2: 0.9990
# Epoch 453/2000
#  - 1s - loss: 9.3069e-04 - coeff_r2: 0.9991 - val_loss: 9.2138e-04 - val_coeff_r2: 0.9991
# Epoch 454/2000
#  - 1s - loss: 9.4068e-04 - coeff_r2: 0.9991 - val_loss: 9.2433e-04 - val_coeff_r2: 0.9991
# Epoch 455/2000
#  - 1s - loss: 9.3376e-04 - coeff_r2: 0.9991 - val_loss: 9.3584e-04 - val_coeff_r2: 0.9991
# Epoch 456/2000
#  - 1s - loss: 9.3465e-04 - coeff_r2: 0.9991 - val_loss: 9.5612e-04 - val_coeff_r2: 0.9990
# Epoch 457/2000
#  - 1s - loss: 9.3562e-04 - coeff_r2: 0.9991 - val_loss: 9.3244e-04 - val_coeff_r2: 0.9991
# Epoch 458/2000
#  - 1s - loss: 9.3350e-04 - coeff_r2: 0.9991 - val_loss: 9.0976e-04 - val_coeff_r2: 0.9991
# Epoch 459/2000
#  - 1s - loss: 9.4149e-04 - coeff_r2: 0.9991 - val_loss: 9.1979e-04 - val_coeff_r2: 0.9991
# Epoch 460/2000
#  - 1s - loss: 9.3591e-04 - coeff_r2: 0.9991 - val_loss: 9.6747e-04 - val_coeff_r2: 0.9990
# Epoch 461/2000
#  - 1s - loss: 9.6208e-04 - coeff_r2: 0.9990 - val_loss: 9.8805e-04 - val_coeff_r2: 0.9990
# Epoch 462/2000
#  - 1s - loss: 9.4237e-04 - coeff_r2: 0.9991 - val_loss: 9.5166e-04 - val_coeff_r2: 0.9990
# Epoch 463/2000
#  - 1s - loss: 9.3368e-04 - coeff_r2: 0.9991 - val_loss: 9.2638e-04 - val_coeff_r2: 0.9991
# Epoch 464/2000
#  - 1s - loss: 9.3784e-04 - coeff_r2: 0.9991 - val_loss: 9.4224e-04 - val_coeff_r2: 0.9991
# Epoch 465/2000
#  - 1s - loss: 9.3100e-04 - coeff_r2: 0.9991 - val_loss: 9.1775e-04 - val_coeff_r2: 0.9991
# Epoch 466/2000
#  - 1s - loss: 9.3960e-04 - coeff_r2: 0.9991 - val_loss: 9.3139e-04 - val_coeff_r2: 0.9991
# Epoch 467/2000
#  - 1s - loss: 9.3145e-04 - coeff_r2: 0.9991 - val_loss: 9.1110e-04 - val_coeff_r2: 0.9991
# Epoch 468/2000
#  - 1s - loss: 9.4336e-04 - coeff_r2: 0.9991 - val_loss: 9.4629e-04 - val_coeff_r2: 0.9990
# Epoch 469/2000
#  - 1s - loss: 9.3112e-04 - coeff_r2: 0.9991 - val_loss: 9.0478e-04 - val_coeff_r2: 0.9991
# Epoch 470/2000
#  - 1s - loss: 9.2432e-04 - coeff_r2: 0.9991 - val_loss: 9.2430e-04 - val_coeff_r2: 0.9991
# Epoch 471/2000
#  - 1s - loss: 9.2669e-04 - coeff_r2: 0.9991 - val_loss: 9.1483e-04 - val_coeff_r2: 0.9991
# Epoch 472/2000
#  - 1s - loss: 9.2759e-04 - coeff_r2: 0.9991 - val_loss: 9.1311e-04 - val_coeff_r2: 0.9991
# Epoch 473/2000
#  - 1s - loss: 9.2477e-04 - coeff_r2: 0.9991 - val_loss: 9.2900e-04 - val_coeff_r2: 0.9991
# Epoch 474/2000
#  - 1s - loss: 9.3788e-04 - coeff_r2: 0.9991 - val_loss: 9.2829e-04 - val_coeff_r2: 0.9991
# Epoch 475/2000
#  - 1s - loss: 9.4814e-04 - coeff_r2: 0.9991 - val_loss: 9.3925e-04 - val_coeff_r2: 0.9991
# Epoch 476/2000
#  - 1s - loss: 9.3502e-04 - coeff_r2: 0.9991 - val_loss: 9.8325e-04 - val_coeff_r2: 0.9990
# Epoch 477/2000
#  - 1s - loss: 9.3855e-04 - coeff_r2: 0.9991 - val_loss: 9.3511e-04 - val_coeff_r2: 0.9991
# Epoch 478/2000
#  - 1s - loss: 9.2903e-04 - coeff_r2: 0.9991 - val_loss: 9.3382e-04 - val_coeff_r2: 0.9991
# Epoch 479/2000
#  - 1s - loss: 9.4336e-04 - coeff_r2: 0.9991 - val_loss: 9.0250e-04 - val_coeff_r2: 0.9991
# Epoch 480/2000
#  - 1s - loss: 9.4191e-04 - coeff_r2: 0.9991 - val_loss: 9.2219e-04 - val_coeff_r2: 0.9991
# Epoch 481/2000
#  - 1s - loss: 9.2381e-04 - coeff_r2: 0.9991 - val_loss: 9.1461e-04 - val_coeff_r2: 0.9991
# Epoch 482/2000
#  - 1s - loss: 9.2850e-04 - coeff_r2: 0.9991 - val_loss: 9.2250e-04 - val_coeff_r2: 0.9991
# Epoch 483/2000
#  - 1s - loss: 9.2790e-04 - coeff_r2: 0.9991 - val_loss: 9.1540e-04 - val_coeff_r2: 0.9991
# ...
#  - 1s - loss: 6.9584e-04 - coeff_r2: 0.9993 - val_loss: 6.8240e-04 - val_coeff_r2: 0.9993
# Epoch 1851/2000
#  - 1s - loss: 7.0017e-04 - coeff_r2: 0.9993 - val_loss: 6.8913e-04 - val_coeff_r2: 0.9993
# Epoch 1852/2000
#  - 1s - loss: 7.0023e-04 - coeff_r2: 0.9993 - val_loss: 7.3272e-04 - val_coeff_r2: 0.9993
# Epoch 1853/2000
#  - 1s - loss: 7.1552e-04 - coeff_r2: 0.9993 - val_loss: 7.2114e-04 - val_coeff_r2: 0.9993
# Epoch 1854/2000
#  - 1s - loss: 7.0686e-04 - coeff_r2: 0.9993 - val_loss: 6.8658e-04 - val_coeff_r2: 0.9993
# Epoch 1855/2000
#  - 1s - loss: 7.0337e-04 - coeff_r2: 0.9993 - val_loss: 6.7927e-04 - val_coeff_r2: 0.9993
# Epoch 1856/2000
#  - 1s - loss: 6.8964e-04 - coeff_r2: 0.9993 - val_loss: 7.1809e-04 - val_coeff_r2: 0.9993
# Epoch 1857/2000
#  - 1s - loss: 6.9000e-04 - coeff_r2: 0.9993 - val_loss: 7.1043e-04 - val_coeff_r2: 0.9993
# Epoch 1858/2000
#  - 1s - loss: 7.0020e-04 - coeff_r2: 0.9993 - val_loss: 6.7798e-04 - val_coeff_r2: 0.9993
# Epoch 1859/2000
#  - 1s - loss: 6.8891e-04 - coeff_r2: 0.9993 - val_loss: 6.8733e-04 - val_coeff_r2: 0.9993
# Epoch 1860/2000
#  - 1s - loss: 7.0520e-04 - coeff_r2: 0.9993 - val_loss: 6.9315e-04 - val_coeff_r2: 0.9993
# Epoch 1861/2000
#  - 1s - loss: 6.9907e-04 - coeff_r2: 0.9993 - val_loss: 6.9529e-04 - val_coeff_r2: 0.9993
# Epoch 1862/2000
#  - 1s - loss: 7.0571e-04 - coeff_r2: 0.9993 - val_loss: 7.1575e-04 - val_coeff_r2: 0.9993
# Epoch 1863/2000
#  - 1s - loss: 7.1663e-04 - coeff_r2: 0.9993 - val_loss: 7.6702e-04 - val_coeff_r2: 0.9992
# Epoch 1864/2000
#  - 1s - loss: 7.0762e-04 - coeff_r2: 0.9993 - val_loss: 6.9042e-04 - val_coeff_r2: 0.9993
# Epoch 1865/2000
#  - 1s - loss: 6.9219e-04 - coeff_r2: 0.9993 - val_loss: 6.7557e-04 - val_coeff_r2: 0.9993
# Epoch 1866/2000
#  - 1s - loss: 6.8640e-04 - coeff_r2: 0.9993 - val_loss: 7.1885e-04 - val_coeff_r2: 0.9993
# Epoch 1867/2000
#  - 1s - loss: 7.0206e-04 - coeff_r2: 0.9993 - val_loss: 6.7813e-04 - val_coeff_r2: 0.9993
# Epoch 1868/2000
#  - 1s - loss: 6.9645e-04 - coeff_r2: 0.9993 - val_loss: 6.8034e-04 - val_coeff_r2: 0.9993
# Epoch 1869/2000
#  - 1s - loss: 7.0380e-04 - coeff_r2: 0.9993 - val_loss: 6.7135e-04 - val_coeff_r2: 0.9993
# Epoch 1870/2000
#  - 1s - loss: 6.8638e-04 - coeff_r2: 0.9993 - val_loss: 7.4676e-04 - val_coeff_r2: 0.9992
# Epoch 1871/2000
#  - 1s - loss: 6.9150e-04 - coeff_r2: 0.9993 - val_loss: 6.9465e-04 - val_coeff_r2: 0.9993
# Epoch 1872/2000
#  - 1s - loss: 6.9495e-04 - coeff_r2: 0.9993 - val_loss: 7.0022e-04 - val_coeff_r2: 0.9993
# Epoch 1873/2000
#  - 1s - loss: 7.0351e-04 - coeff_r2: 0.9993 - val_loss: 7.2603e-04 - val_coeff_r2: 0.9993
# Epoch 1874/2000
#  - 1s - loss: 6.9730e-04 - coeff_r2: 0.9993 - val_loss: 6.9536e-04 - val_coeff_r2: 0.9993
# Epoch 1875/2000
#  - 1s - loss: 6.9299e-04 - coeff_r2: 0.9993 - val_loss: 7.5163e-04 - val_coeff_r2: 0.9992
# Epoch 1876/2000
#  - 1s - loss: 7.3658e-04 - coeff_r2: 0.9993 - val_loss: 7.4130e-04 - val_coeff_r2: 0.9993
# Epoch 1877/2000
#  - 1s - loss: 6.9654e-04 - coeff_r2: 0.9993 - val_loss: 6.8191e-04 - val_coeff_r2: 0.9993
# Epoch 1878/2000
#  - 1s - loss: 6.8878e-04 - coeff_r2: 0.9993 - val_loss: 6.9113e-04 - val_coeff_r2: 0.9993
# Epoch 1879/2000
#  - 1s - loss: 6.9007e-04 - coeff_r2: 0.9993 - val_loss: 7.2196e-04 - val_coeff_r2: 0.9993
# Epoch 1880/2000
#  - 1s - loss: 7.1416e-04 - coeff_r2: 0.9993 - val_loss: 7.6597e-04 - val_coeff_r2: 0.9992
# Epoch 1881/2000
#  - 1s - loss: 6.8876e-04 - coeff_r2: 0.9993 - val_loss: 7.1881e-04 - val_coeff_r2: 0.9993
# Epoch 1882/2000
#  - 1s - loss: 7.1185e-04 - coeff_r2: 0.9993 - val_loss: 6.9184e-04 - val_coeff_r2: 0.9993
# Epoch 1883/2000
#  - 1s - loss: 6.8721e-04 - coeff_r2: 0.9993 - val_loss: 6.8571e-04 - val_coeff_r2: 0.9993
# Epoch 1884/2000
#  - 1s - loss: 6.8775e-04 - coeff_r2: 0.9993 - val_loss: 6.8804e-04 - val_coeff_r2: 0.9993
# Epoch 1885/2000
#  - 1s - loss: 6.8751e-04 - coeff_r2: 0.9993 - val_loss: 6.9588e-04 - val_coeff_r2: 0.9993
# Epoch 1886/2000
#  - 1s - loss: 6.9280e-04 - coeff_r2: 0.9993 - val_loss: 6.7586e-04 - val_coeff_r2: 0.9993
# Epoch 1887/2000
#  - 1s - loss: 6.9146e-04 - coeff_r2: 0.9993 - val_loss: 6.7602e-04 - val_coeff_r2: 0.9993
# Epoch 1888/2000
#  - 1s - loss: 6.8704e-04 - coeff_r2: 0.9993 - val_loss: 7.0515e-04 - val_coeff_r2: 0.9993
# Epoch 1889/2000
#  - 1s - loss: 6.8565e-04 - coeff_r2: 0.9993 - val_loss: 6.8399e-04 - val_coeff_r2: 0.9993
# Epoch 1890/2000
#  - 1s - loss: 6.9125e-04 - coeff_r2: 0.9993 - val_loss: 6.7095e-04 - val_coeff_r2: 0.9993
# Epoch 1891/2000
#  - 1s - loss: 6.8895e-04 - coeff_r2: 0.9993 - val_loss: 7.0742e-04 - val_coeff_r2: 0.9993
# Epoch 1892/2000
#  - 1s - loss: 7.3399e-04 - coeff_r2: 0.9993 - val_loss: 7.4951e-04 - val_coeff_r2: 0.9992
# Epoch 1893/2000
#  - 1s - loss: 7.2206e-04 - coeff_r2: 0.9993 - val_loss: 6.8424e-04 - val_coeff_r2: 0.9993
# Epoch 1894/2000
#  - 1s - loss: 6.9545e-04 - coeff_r2: 0.9993 - val_loss: 6.7770e-04 - val_coeff_r2: 0.9993
# Epoch 1895/2000
#  - 1s - loss: 6.9778e-04 - coeff_r2: 0.9993 - val_loss: 6.8477e-04 - val_coeff_r2: 0.9993
# Epoch 1896/2000
#  - 1s - loss: 6.9432e-04 - coeff_r2: 0.9993 - val_loss: 6.9092e-04 - val_coeff_r2: 0.9993
# Epoch 1897/2000
#  - 1s - loss: 6.8864e-04 - coeff_r2: 0.9993 - val_loss: 6.7596e-04 - val_coeff_r2: 0.9993
# Epoch 1898/2000
#  - 1s - loss: 6.8530e-04 - coeff_r2: 0.9993 - val_loss: 6.8257e-04 - val_coeff_r2: 0.9993
# Epoch 1899/2000
#  - 1s - loss: 6.9329e-04 - coeff_r2: 0.9993 - val_loss: 7.7215e-04 - val_coeff_r2: 0.9992
# Epoch 1900/2000
#  - 1s - loss: 6.9812e-04 - coeff_r2: 0.9993 - val_loss: 6.7154e-04 - val_coeff_r2: 0.9993
# Epoch 1901/2000
#  - 1s - loss: 6.8043e-04 - coeff_r2: 0.9993 - val_loss: 6.9357e-04 - val_coeff_r2: 0.9993
# Epoch 1902/2000
#  - 1s - loss: 6.8976e-04 - coeff_r2: 0.9993 - val_loss: 6.9676e-04 - val_coeff_r2: 0.9993
# Epoch 1903/2000
#  - 1s - loss: 6.9876e-04 - coeff_r2: 0.9993 - val_loss: 7.0507e-04 - val_coeff_r2: 0.9993
# Epoch 1904/2000
#  - 1s - loss: 6.8850e-04 - coeff_r2: 0.9993 - val_loss: 6.8666e-04 - val_coeff_r2: 0.9993
# Epoch 1905/2000
#  - 1s - loss: 6.9552e-04 - coeff_r2: 0.9993 - val_loss: 7.0257e-04 - val_coeff_r2: 0.9993
# Epoch 1906/2000
#  - 1s - loss: 6.8154e-04 - coeff_r2: 0.9993 - val_loss: 6.8909e-04 - val_coeff_r2: 0.9993
# Epoch 1907/2000
#  - 1s - loss: 6.8564e-04 - coeff_r2: 0.9993 - val_loss: 6.7187e-04 - val_coeff_r2: 0.9993
# Epoch 1908/2000
#  - 1s - loss: 6.8372e-04 - coeff_r2: 0.9993 - val_loss: 6.8614e-04 - val_coeff_r2: 0.9993
# Epoch 1909/2000
#  - 1s - loss: 6.8370e-04 - coeff_r2: 0.9993 - val_loss: 6.7448e-04 - val_coeff_r2: 0.9993
# Epoch 1910/2000
#  - 1s - loss: 6.8010e-04 - coeff_r2: 0.9993 - val_loss: 6.9035e-04 - val_coeff_r2: 0.9993
# Epoch 1911/2000
#  - 1s - loss: 6.9590e-04 - coeff_r2: 0.9993 - val_loss: 6.9023e-04 - val_coeff_r2: 0.9993
# Epoch 1912/2000
#  - 1s - loss: 6.9202e-04 - coeff_r2: 0.9993 - val_loss: 6.9150e-04 - val_coeff_r2: 0.9993
# Epoch 1913/2000
#  - 1s - loss: 6.8802e-04 - coeff_r2: 0.9993 - val_loss: 6.7587e-04 - val_coeff_r2: 0.9993
# Epoch 1914/2000
#  - 1s - loss: 6.9569e-04 - coeff_r2: 0.9993 - val_loss: 6.9684e-04 - val_coeff_r2: 0.9993
# Epoch 1915/2000
#  - 1s - loss: 7.0020e-04 - coeff_r2: 0.9993 - val_loss: 7.0156e-04 - val_coeff_r2: 0.9993
# Epoch 1916/2000
#  - 1s - loss: 6.8982e-04 - coeff_r2: 0.9993 - val_loss: 7.4278e-04 - val_coeff_r2: 0.9993
# Epoch 1917/2000
#  - 1s - loss: 6.9841e-04 - coeff_r2: 0.9993 - val_loss: 6.9192e-04 - val_coeff_r2: 0.9993
# Epoch 1918/2000
#  - 1s - loss: 6.8302e-04 - coeff_r2: 0.9993 - val_loss: 6.7830e-04 - val_coeff_r2: 0.9993
# Epoch 1919/2000
#  - 1s - loss: 6.8080e-04 - coeff_r2: 0.9993 - val_loss: 6.7530e-04 - val_coeff_r2: 0.9993
# Epoch 1920/2000
#  - 1s - loss: 7.0945e-04 - coeff_r2: 0.9993 - val_loss: 7.2675e-04 - val_coeff_r2: 0.9993
# Epoch 1921/2000
#  - 1s - loss: 7.1180e-04 - coeff_r2: 0.9993 - val_loss: 6.8159e-04 - val_coeff_r2: 0.9993
# Epoch 1922/2000
#  - 1s - loss: 6.9172e-04 - coeff_r2: 0.9993 - val_loss: 6.9842e-04 - val_coeff_r2: 0.9993
# Epoch 1923/2000
#  - 1s - loss: 6.9059e-04 - coeff_r2: 0.9993 - val_loss: 6.9006e-04 - val_coeff_r2: 0.9993
# Epoch 1924/2000
#  - 1s - loss: 6.8385e-04 - coeff_r2: 0.9993 - val_loss: 6.8349e-04 - val_coeff_r2: 0.9993
# Epoch 1925/2000
#  - 1s - loss: 6.8658e-04 - coeff_r2: 0.9993 - val_loss: 7.1517e-04 - val_coeff_r2: 0.9993
# Epoch 1926/2000
#  - 1s - loss: 6.9087e-04 - coeff_r2: 0.9993 - val_loss: 7.1245e-04 - val_coeff_r2: 0.9993
# Epoch 1927/2000
#  - 1s - loss: 7.1179e-04 - coeff_r2: 0.9993 - val_loss: 7.5890e-04 - val_coeff_r2: 0.9992
# Epoch 1928/2000
#  - 1s - loss: 6.8874e-04 - coeff_r2: 0.9993 - val_loss: 6.8930e-04 - val_coeff_r2: 0.9993
# Epoch 1929/2000
#  - 1s - loss: 7.0860e-04 - coeff_r2: 0.9993 - val_loss: 7.1073e-04 - val_coeff_r2: 0.9993
# Epoch 1930/2000
#  - 1s - loss: 6.8239e-04 - coeff_r2: 0.9993 - val_loss: 6.7094e-04 - val_coeff_r2: 0.9993
# Epoch 1931/2000
#  - 1s - loss: 6.9574e-04 - coeff_r2: 0.9993 - val_loss: 7.1657e-04 - val_coeff_r2: 0.9993
# Epoch 1932/2000
#  - 1s - loss: 6.8276e-04 - coeff_r2: 0.9993 - val_loss: 7.2576e-04 - val_coeff_r2: 0.9993
# Epoch 1933/2000
#  - 1s - loss: 6.8872e-04 - coeff_r2: 0.9993 - val_loss: 6.9668e-04 - val_coeff_r2: 0.9993
# Epoch 1934/2000
#  - 1s - loss: 7.0115e-04 - coeff_r2: 0.9993 - val_loss: 6.8747e-04 - val_coeff_r2: 0.9993
# Epoch 1935/2000
#  - 1s - loss: 6.8233e-04 - coeff_r2: 0.9993 - val_loss: 6.8900e-04 - val_coeff_r2: 0.9993
# Epoch 1936/2000
#  - 1s - loss: 6.8632e-04 - coeff_r2: 0.9993 - val_loss: 7.9638e-04 - val_coeff_r2: 0.9992
# Epoch 1937/2000
#  - 1s - loss: 7.1588e-04 - coeff_r2: 0.9993 - val_loss: 7.0799e-04 - val_coeff_r2: 0.9993
# Epoch 1938/2000
#  - 1s - loss: 6.8795e-04 - coeff_r2: 0.9993 - val_loss: 6.8205e-04 - val_coeff_r2: 0.9993
# Epoch 1939/2000
#  - 1s - loss: 6.9782e-04 - coeff_r2: 0.9993 - val_loss: 6.8564e-04 - val_coeff_r2: 0.9993
# Epoch 1940/2000
#  - 1s - loss: 6.9836e-04 - coeff_r2: 0.9993 - val_loss: 6.7266e-04 - val_coeff_r2: 0.9993
# Epoch 1941/2000
#  - 1s - loss: 6.8972e-04 - coeff_r2: 0.9993 - val_loss: 7.0158e-04 - val_coeff_r2: 0.9993
# Epoch 1942/2000
#  - 1s - loss: 6.9302e-04 - coeff_r2: 0.9993 - val_loss: 6.7838e-04 - val_coeff_r2: 0.9993
# Epoch 1943/2000
#  - 1s - loss: 7.0516e-04 - coeff_r2: 0.9993 - val_loss: 7.1922e-04 - val_coeff_r2: 0.9993
# Epoch 1944/2000
#  - 1s - loss: 7.0916e-04 - coeff_r2: 0.9993 - val_loss: 7.1295e-04 - val_coeff_r2: 0.9993
# Epoch 1945/2000
#  - 1s - loss: 6.9049e-04 - coeff_r2: 0.9993 - val_loss: 7.0188e-04 - val_coeff_r2: 0.9993
# Epoch 1946/2000
#  - 1s - loss: 6.8738e-04 - coeff_r2: 0.9993 - val_loss: 7.2572e-04 - val_coeff_r2: 0.9993
# Epoch 1947/2000
#  - 1s - loss: 6.9218e-04 - coeff_r2: 0.9993 - val_loss: 7.1524e-04 - val_coeff_r2: 0.9993
# Epoch 1948/2000
#  - 1s - loss: 6.9543e-04 - coeff_r2: 0.9993 - val_loss: 6.8866e-04 - val_coeff_r2: 0.9993
# Epoch 1949/2000
#  - 1s - loss: 6.8606e-04 - coeff_r2: 0.9993 - val_loss: 6.9105e-04 - val_coeff_r2: 0.9993
# Epoch 1950/2000
#  - 1s - loss: 6.9662e-04 - coeff_r2: 0.9993 - val_loss: 6.8366e-04 - val_coeff_r2: 0.9993
# Epoch 1951/2000
#  - 1s - loss: 6.9767e-04 - coeff_r2: 0.9993 - val_loss: 6.9250e-04 - val_coeff_r2: 0.9993
# Epoch 1952/2000
#  - 1s - loss: 6.8598e-04 - coeff_r2: 0.9993 - val_loss: 6.7775e-04 - val_coeff_r2: 0.9993
# Epoch 1953/2000
#  - 1s - loss: 6.8919e-04 - coeff_r2: 0.9993 - val_loss: 6.7540e-04 - val_coeff_r2: 0.9993
# Epoch 1954/2000
#  - 1s - loss: 6.9874e-04 - coeff_r2: 0.9993 - val_loss: 6.9220e-04 - val_coeff_r2: 0.9993
# Epoch 1955/2000
#  - 1s - loss: 6.8977e-04 - coeff_r2: 0.9993 - val_loss: 6.8760e-04 - val_coeff_r2: 0.9993
# Epoch 1956/2000
#  - 1s - loss: 6.7960e-04 - coeff_r2: 0.9993 - val_loss: 6.7355e-04 - val_coeff_r2: 0.9993
# Epoch 1957/2000
#  - 1s - loss: 6.8616e-04 - coeff_r2: 0.9993 - val_loss: 7.3514e-04 - val_coeff_r2: 0.9993
# Epoch 1958/2000
#  - 1s - loss: 6.8311e-04 - coeff_r2: 0.9993 - val_loss: 6.9620e-04 - val_coeff_r2: 0.9993
# Epoch 1959/2000
#  - 1s - loss: 6.7851e-04 - coeff_r2: 0.9993 - val_loss: 6.7691e-04 - val_coeff_r2: 0.9993
# Epoch 1960/2000
#  - 1s - loss: 6.8705e-04 - coeff_r2: 0.9993 - val_loss: 6.8239e-04 - val_coeff_r2: 0.9993
# Epoch 1961/2000
#  - 1s - loss: 6.8740e-04 - coeff_r2: 0.9993 - val_loss: 7.0472e-04 - val_coeff_r2: 0.9993
# Epoch 1962/2000
#  - 1s - loss: 6.8338e-04 - coeff_r2: 0.9993 - val_loss: 6.7884e-04 - val_coeff_r2: 0.9993
# Epoch 1963/2000
#  - 1s - loss: 6.9779e-04 - coeff_r2: 0.9993 - val_loss: 6.8191e-04 - val_coeff_r2: 0.9993
# Epoch 1964/2000
#  - 1s - loss: 6.9181e-04 - coeff_r2: 0.9993 - val_loss: 6.9096e-04 - val_coeff_r2: 0.9993
# Epoch 1965/2000
#  - 1s - loss: 6.8208e-04 - coeff_r2: 0.9993 - val_loss: 6.7613e-04 - val_coeff_r2: 0.9993
# Epoch 1966/2000
#  - 1s - loss: 7.1906e-04 - coeff_r2: 0.9993 - val_loss: 7.7062e-04 - val_coeff_r2: 0.9992
# Epoch 1967/2000
#  - 1s - loss: 7.3585e-04 - coeff_r2: 0.9993 - val_loss: 6.9478e-04 - val_coeff_r2: 0.9993
# Epoch 1968/2000
#  - 1s - loss: 6.9242e-04 - coeff_r2: 0.9993 - val_loss: 6.7605e-04 - val_coeff_r2: 0.9993
# Epoch 1969/2000
#  - 1s - loss: 6.9934e-04 - coeff_r2: 0.9993 - val_loss: 6.8727e-04 - val_coeff_r2: 0.9993
# Epoch 1970/2000
#  - 1s - loss: 6.8963e-04 - coeff_r2: 0.9993 - val_loss: 6.7015e-04 - val_coeff_r2: 0.9993
# Epoch 1971/2000
#  - 1s - loss: 6.8366e-04 - coeff_r2: 0.9993 - val_loss: 6.7575e-04 - val_coeff_r2: 0.9993
# Epoch 1972/2000
#  - 1s - loss: 6.9188e-04 - coeff_r2: 0.9993 - val_loss: 6.8762e-04 - val_coeff_r2: 0.9993
# Epoch 1973/2000
#  - 1s - loss: 6.9309e-04 - coeff_r2: 0.9993 - val_loss: 7.0300e-04 - val_coeff_r2: 0.9993
# Epoch 1974/2000
#  - 1s - loss: 7.1359e-04 - coeff_r2: 0.9993 - val_loss: 7.0688e-04 - val_coeff_r2: 0.9993
# Epoch 1975/2000
#  - 1s - loss: 6.9825e-04 - coeff_r2: 0.9993 - val_loss: 6.7837e-04 - val_coeff_r2: 0.9993
# Epoch 1976/2000
#  - 1s - loss: 6.8641e-04 - coeff_r2: 0.9993 - val_loss: 6.9015e-04 - val_coeff_r2: 0.9993
# Epoch 1977/2000
#  - 1s - loss: 6.8781e-04 - coeff_r2: 0.9993 - val_loss: 6.7638e-04 - val_coeff_r2: 0.9993
# Epoch 1978/2000
#  - 1s - loss: 6.8680e-04 - coeff_r2: 0.9993 - val_loss: 6.8960e-04 - val_coeff_r2: 0.9993
# Epoch 1979/2000
#  - 1s - loss: 6.8694e-04 - coeff_r2: 0.9993 - val_loss: 6.7942e-04 - val_coeff_r2: 0.9993
# Epoch 1980/2000
#  - 1s - loss: 6.7855e-04 - coeff_r2: 0.9993 - val_loss: 6.7076e-04 - val_coeff_r2: 0.9993
# Epoch 1981/2000
#  - 1s - loss: 6.8677e-04 - coeff_r2: 0.9993 - val_loss: 6.8897e-04 - val_coeff_r2: 0.9993
# Epoch 1982/2000
#  - 1s - loss: 6.8056e-04 - coeff_r2: 0.9993 - val_loss: 6.7798e-04 - val_coeff_r2: 0.9993
# Epoch 1983/2000
#  - 1s - loss: 6.8844e-04 - coeff_r2: 0.9993 - val_loss: 7.1452e-04 - val_coeff_r2: 0.9993
# Epoch 1984/2000
#  - 1s - loss: 7.0237e-04 - coeff_r2: 0.9993 - val_loss: 6.7156e-04 - val_coeff_r2: 0.9993
# Epoch 1985/2000
#  - 1s - loss: 6.7966e-04 - coeff_r2: 0.9993 - val_loss: 6.8617e-04 - val_coeff_r2: 0.9993
# Epoch 1986/2000
#  - 1s - loss: 6.8451e-04 - coeff_r2: 0.9993 - val_loss: 6.8848e-04 - val_coeff_r2: 0.9993
# Epoch 1987/2000
#  - 1s - loss: 6.9614e-04 - coeff_r2: 0.9993 - val_loss: 6.8613e-04 - val_coeff_r2: 0.9993
# Epoch 1988/2000
#  - 1s - loss: 6.8093e-04 - coeff_r2: 0.9993 - val_loss: 6.8276e-04 - val_coeff_r2: 0.9993
# Epoch 1989/2000
#  - 1s - loss: 6.8201e-04 - coeff_r2: 0.9993 - val_loss: 6.8232e-04 - val_coeff_r2: 0.9993
# Epoch 1990/2000
#  - 1s - loss: 6.9036e-04 - coeff_r2: 0.9993 - val_loss: 7.0464e-04 - val_coeff_r2: 0.9993
# Epoch 1991/2000
#  - 1s - loss: 6.9436e-04 - coeff_r2: 0.9993 - val_loss: 6.9876e-04 - val_coeff_r2: 0.9993
# Epoch 1992/2000
#  - 1s - loss: 6.7767e-04 - coeff_r2: 0.9993 - val_loss: 6.8657e-04 - val_coeff_r2: 0.9993
# Epoch 1993/2000
#  - 1s - loss: 6.9638e-04 - coeff_r2: 0.9993 - val_loss: 6.9960e-04 - val_coeff_r2: 0.9993
# Epoch 1994/2000
#  - 1s - loss: 6.8036e-04 - coeff_r2: 0.9993 - val_loss: 6.9522e-04 - val_coeff_r2: 0.9993
# Epoch 1995/2000
#  - 1s - loss: 7.0201e-04 - coeff_r2: 0.9993 - val_loss: 6.7729e-04 - val_coeff_r2: 0.9993
# Epoch 1996/2000
#  - 1s - loss: 6.8856e-04 - coeff_r2: 0.9993 - val_loss: 7.0308e-04 - val_coeff_r2: 0.9993
# Epoch 1997/2000
#  - 1s - loss: 6.8671e-04 - coeff_r2: 0.9993 - val_loss: 6.8358e-04 - val_coeff_r2: 0.9993
# Epoch 1998/2000
#  - 1s - loss: 6.8781e-04 - coeff_r2: 0.9993 - val_loss: 6.7909e-04 - val_coeff_r2: 0.9993
# Epoch 1999/2000
#  - 1s - loss: 6.8720e-04 - coeff_r2: 0.9993 - val_loss: 7.0791e-04 - val_coeff_r2: 0.9993
# Epoch 2000/2000
#  - 1s - loss: 6.9428e-04 - coeff_r2: 0.9993 - val_loss: 6.8118e-04 - val_coeff_r2: 0.9993
